# %%
#pip install requests pandas fake_useragent bs4 langid pycountry nltk

# %%
import  requests
from bs4 import BeautifulSoup
from fake_useragent import UserAgent #used to create fake user inorder for requests
import pandas as pd
import os

url = 'https://dev.to/latest'

ua=UserAgent()
userAgent= ua.random
headers= {'User_Agent': userAgent}
page = requests.get(url, headers = headers)
soup= BeautifulSoup(page.content,'html.parser')

# %%
blog_box = soup.find_all('div' ,'crayons-story')

links = [] 
titles = [] 
time_uploaded = []  
authors = []
tags = []
reading_times = []


for box in blog_box:
    #links
    if box.find('h2', class_ = 'crayons-story__title') is not None:
        link =  box.find('h2', class_ = 'crayons-story__title').a
        link = link['href']
        links.append(link)
    else:
        links.append('None')  
        
    #titles    
    if box.find('h2', class_ = 'crayons-story__title') is not None:
        title =  box.find('h2', class_ = 'crayons-story__title')
        titles.append(title.text.replace('\n','').strip())
    else:
        titles.append('None')          

    #time_uploaded 
    if box.find('time', attrs={'datetime': True}) is not None:
        time_upload =  box.find('time', attrs={'datetime': True})
        time_upload= time_upload['datetime']
        time_uploaded.append (time_upload)
    else:
        time_uploaded.append('None') 

    #authors 
    if box.find('a', class_ = 'crayons-story__secondary fw-medium m:hidden') is not None:
        author =  box.find('a', class_ = 'crayons-story__secondary fw-medium m:hidden')
        authors.append(author.text.replace('\n','').strip())
    else:
        authors.append('None')  


    #tags  
    if box.find('div', class_ = 'crayons-story__tags') is not None:
        tag =  box.find('div', class_ = 'crayons-story__tags')
        tags.append(tag.text.replace('\n',' ').strip())
    else:
        tags.append('None')
        
 #reading_time  
    if box.find('div', class_ = 'crayons-story__save') is not None:
        reading_time  =  box.find('div', class_ = 'crayons-story__save')
        reading_times.append(reading_time.text.replace('\n',' ').strip())
    else:
        reading_times.append('None')  
  
  
df = pd.DataFrame(
    {
    'Link' : links,
    'Title' : titles,
    'Time_Uploaded' : time_uploaded ,
    'Authors' : authors,
    'Tags' : tags,
    'Reading_Time' : reading_times
    }
) 

df= df[ df['Link'] != 'None']

df
# Out:
#                                                  Link  \
# 2   https://dev.to/qingkouwei/nested-class-state-o...
# 3   https://dev.to/qingkouwei/intercepting-touch-e...
# 4   https://dev.to/qingkouwei/using-semi-modal-in-...
# 5   https://dev.to/qingkouwei/text-content-font-ha...
# 6   https://dev.to/qingkouwei/swiper-style-waterfl...
# 7   https://dev.to/aloe/arkui-xtong-guo-stagemo-xi...
# 8   https://dev.to/sidtalesara/arc-browser-is-dead...
# 9   https://dev.to/qingkouwei/pixel-unit-conversio...
# 10  https://dev.to/qingkouwei/page-parameter-passi...
# 11               https://dev.to/thestorybookdev/-3ci7
# 12  https://dev.to/joe111/introducing-neo-ui-mui-i...
# 13  https://dev.to/ramunarasinga-11/remeda-package...
# 14  https://dev.to/asim786521/why-udp-powers-strea...
# 15  https://dev.to/ruuma_fb53ad7177cba32d962/nuxt-...
# 16  https://dev.to/1suleyman/what-is-serverless-co...
# 17  https://dev.to/noorsimar/from-500-lines-to-150...
# 18  https://dev.to/aloe/arkui-xkuang-jia-loginterf...
# 19  https://dev.to/gail_axelrod_03844667f64d/we-ga...
# 20  https://dev.to/devopsfundamentals/machine-lear...
# 21  https://dev.to/aloe/arkui-xgou-jian-androidpin...
# 22  https://dev.to/aloe/arkui-xzai-androidshang-sh...
# 23  https://dev.to/hoangquochung1110/bo-sung-ngu-c...
# 24  https://dev.to/carrie_luo1/safeline-waf-high-a...
# 25  https://dev.to/aloe/arkui-xping-tai-chai-yi-hu...
# 26  https://dev.to/sgchris/using-phantomdata-and-z...
#
#                                                 Title         Time_Uploaded  \
# 2   Nested Class State Observation, Text & Emoji D...  2025-06-25T15:55:42Z
# 3   Intercepting Touch Events, Disabling Side Swip...  2025-06-25T15:54:13Z
# 4   Using Semi-modal in Lists, Custom Toast, Popup...  2025-06-25T15:52:29Z
# 5   Text Content Font, Half-screen Routing, Input ...  2025-06-25T15:51:06Z
# 6   Swiper Style, WaterFlow, Clipboard, Manual Tra...  2025-06-25T15:49:43Z
# 7                   ArkUI-X通过Stage模型开发Android端应用指南(二)  2025-06-25T15:48:48Z
# 8   Arc Browser is Dead, and Dia Isn’t the Answer:...  2025-06-25T15:48:35Z
# 9   Pixel Unit Conversion, Dialog Declaration Issu...  2025-06-25T15:48:05Z
# 10  Page Parameter Passing, Popup Disable Blank Cl...  2025-06-25T15:46:07Z
# 11                                            [Boost]  2025-06-25T15:45:49Z
# 12  Introducing Neo UI – MUI-Inspired Component Li...  2025-06-25T15:42:39Z
# 13                remeda package in 0.email codebase.  2025-06-25T15:30:00Z
# 14  Why UDP Powers Streaming, Gaming, and Real-Tim...  2025-06-25T15:22:53Z
# 15  Nuxt 3 + Google OAuth (PKCE) Minimal Setup Gui...  2025-06-25T15:22:48Z
# 16  ☁️ What Is Serverless Computing? (And Why It’s...  2025-06-25T15:22:37Z
# 17  From 500+ Lines to 150: How I Refactored My Am...  2025-06-25T15:22:09Z
# 18                          ArkUI-X框架LogInterface使用指南  2025-06-25T15:19:15Z
# 19    We Gave Our Engineers AI. Here's What Happened.  2025-06-25T15:19:14Z
# 20  Machine Learning Fundamentals: active learning...  2025-06-25T15:17:43Z
# 21                           ArkUI-X构建Android平台AAR及使用  2025-06-25T15:15:48Z
# 22                     ArkUI-X在Android上使用Fragment开发指南  2025-06-25T15:14:07Z
# 23  Bổ sung ngữ cảnh cho LLM: Nâng cao độ chính xá...  2025-06-25T15:13:22Z
# 24            SafeLine WAF High Availability Solution  2025-06-25T15:11:41Z
# 25                                       ArkUI-X平台差异化  2025-06-25T15:10:42Z
# 26             Using PhantomData and Zero-Sized Types  2025-06-25T15:10:22Z
#
#                Authors                                         Tags  \
# 2          kouwei qing                               #harmonyosnext
# 3          kouwei qing                               #harmonyosnext
# 4          kouwei qing                               #harmonyosnext
# 5          kouwei qing                               #harmonyosnext
# 6          kouwei qing                               #harmonyosnext
# 7                  龙儿筝
# 8   Siddharth Talesara          #ai #openai #playwright #automation
# 9          kouwei qing                               #harmonyosnext
# 10         kouwei qing                               #harmonyosnext
# 11       Shalom Mathew                #kubernetes #aws #eks #awseks
# 12       Joe Moussally             #reactnative #mui #react #mobile
# 13      Ramu Narasinga              #zero #email #react #opensource
# 14          Asim786521                  #udp #streaming #atprotocol
# 15               ruuma               #nuxt #vue #oauth #googlecloud
# 16           1suleyman        #aws #cloud #beginners #documentation
# 17     Noorsimar Singh      #webscraping #scrapy #scrapeops #python
# 18                 龙儿筝
# 19        Gail Axelrod                            #ai #productivity
# 20  DevOps Fundamental  #machinelearning #ai #activelearningproject
# 21                 龙儿筝
# 22                 龙儿筝
# 23     Quoc-Hung Hoang
# 24              Carrie                 #ha #waf #safeline #security
# 25                 龙儿筝
# 26       Gregory Chris       #programming #rust #learning #tutorial
#
#    Reading_Time
# 2    4 min read
# 3    3 min read
# 4    4 min read
# 5    3 min read
# 6    2 min read
# 7    3 min read
# 8    5 min read
# 9    3 min read
# 10   3 min read
# 11   1 min read
# 12   1 min read
# 13   4 min read
# 14   2 min read
# 15   3 min read
# 16   3 min read
# 17   4 min read
# 18   1 min read
# 19   3 min read
# 20   6 min read
# 21   1 min read
# 22   2 min read
# 23  10 min read
# 24   4 min read
# 25   1 min read
# 26   4 min read

# %%
##Second_url = 'https://dev.to/sejdi_gashi/live-and-online-our-food-waste-reduction-platform-is-almost-ready-5dfi'
article = []
article_link = []

def get_full_content (Second_url):
    ua=UserAgent()
    userAgent= ua.random
    headers= {'User_Agent': userAgent}
    page = requests.get(Second_url, headers = headers)
    soup= BeautifulSoup(page.content,'html.parser')
    print(Second_url)

    content = soup.find ('div',class_='crayons-article__main')
    paragrphs = content.find_all('p')

    contents = []
    for i in paragrphs:
        contents.append(i.text.replace('\n',' '))
    
    string  = ' '.join(contents)
    article.append (string)
    article_link.append(Second_url)

for i in df.Link:
    get_full_content(i)
article_df = pd.DataFrame(
      {
      'Article_Content' : article,
      'Link' : article_link
      }
    )

article_df
# Out:
# https://dev.to/qingkouwei/nested-class-state-observation-text-emoji-display-dynamic-screenshot-34nk
# https://dev.to/qingkouwei/intercepting-touch-events-disabling-side-swipe-back-data-driven-ui-text-ellipsis-trigger-34k9
# https://dev.to/qingkouwei/using-semi-modal-in-lists-custom-toast-popup-following-image-base64-encoding-routing-49c7
# https://dev.to/qingkouwei/text-content-font-half-screen-routing-input-cursor-movement-monitoring-didbuild-4edd
# https://dev.to/qingkouwei/swiper-style-waterflow-clipboard-manual-tracing-1a51
# https://dev.to/aloe/arkui-xtong-guo-stagemo-xing-kai-fa-androidduan-ying-yong-zhi-nan-er--321m
# https://dev.to/sidtalesara/arc-browser-is-dead-and-dia-isnt-the-answer-a-deeply-frustrated-honest-review-21e8
# https://dev.to/qingkouwei/pixel-unit-conversion-dialog-declaration-issues-list-nesting-byte-stream-to-image-5dkk
# https://dev.to/qingkouwei/page-parameter-passing-popup-disable-blank-click-to-close-two-way-binding-data-error-3k4h
# https://dev.to/thestorybookdev/-3ci7
# https://dev.to/joe111/introducing-neo-ui-mui-inspired-component-library-for-react-native-5h23
# https://dev.to/ramunarasinga-11/remeda-package-in-0email-codebase-2hik
# https://dev.to/asim786521/why-udp-powers-streaming-gaming-and-real-time-apps-2onb
# https://dev.to/ruuma_fb53ad7177cba32d962/nuxt-3-google-oauth-pkce-minimal-setup-guide-for-pure-spa-csr-1igf
# https://dev.to/1suleyman/what-is-serverless-computing-and-why-its-changing-the-game-on-aws-4g6a
# https://dev.to/noorsimar/from-500-lines-to-150-how-i-refactored-my-amazon-scraper-into-a-clean-scrapy-project-14o3
# https://dev.to/aloe/arkui-xkuang-jia-loginterfaceshi-yong-zhi-nan-1o5
# https://dev.to/gail_axelrod_03844667f64d/we-gave-our-engineers-ai-heres-what-happened-2din
# https://dev.to/devopsfundamentals/machine-learning-fundamentals-active-learning-project-k7k
# https://dev.to/aloe/arkui-xgou-jian-androidping-tai-aarji-shi-yong-3f5n
# https://dev.to/aloe/arkui-xzai-androidshang-shi-yong-fragmentkai-fa-zhi-nan-21b5
# https://dev.to/hoangquochung1110/bo-sung-ngu-canh-cho-llm-nang-cao-do-chinh-xac-va-tin-cay-cho-ung-dung-genai-47ef
# https://dev.to/carrie_luo1/safeline-waf-high-availability-solution-lio
# https://dev.to/aloe/arkui-xping-tai-chai-yi-hua-4fic
# https://dev.to/sgchris/using-phantomdata-and-zero-sized-types-1i2e
#                                       Article_Content  \
# 0   How to observe the state change of field3 in C...
# 1   When nesting a Scroll component within a page,...
# 2   There is a sharing popup-like page that needs ...
# 3   To globally use custom fonts in an app, regist...
# 4   When setting code in Swiper to control both th...
# 5   StageApplication初始化支持以下三种方式 public class HiSta...
# 6   When The Browser Company announced Arc, it fel...
# 7   The UI provides an image with 750 pixels. When...
# 8   How to pass parameters to WindowContent throug...
# 9
# 10  Hey folks 👋 After building multiple products w...
# 11  In this article, we will review remeda package...
# 12  UDP stands for User Datagram Protocol. It is o...
# 13  ✍  Originally published in Japanese on Qiita, ...
# 14  Hey everyone 👋 If you’ve been getting into clo...
# 15  Like many developers, I started Amazon scrapin...
# 16  ArkUI-X框架支持日志拦截能力，Android侧提供原生接口，用于注入LogInterf...
# 17  By Eli Daniel, Head of Engineering, Jellyfish ...
# 18  In Q3 2023, a critical fraud detection model a...
# 19  本教程主要讲述如何利用ArkUI-X SDK完成Android AAR开发，实现基于ArkT...
# 20  本文介绍将ArkUI框架的UIAbility跨平台部署至Android平台Fragment的...
# 21  Các Mô hình Ngôn ngữ Lớn (LLM) là những công c...
# 22  The SafeLine WAF High Availability solution en...
# 23  跨平台使用场景是一套ArkTS代码运行在多个终端设备上，如Android、iOS、OpenH...
# 24  Rust is a language that thrives on safety and ...
#
#                                                  Link
# 0   https://dev.to/qingkouwei/nested-class-state-o...
# 1   https://dev.to/qingkouwei/intercepting-touch-e...
# 2   https://dev.to/qingkouwei/using-semi-modal-in-...
# 3   https://dev.to/qingkouwei/text-content-font-ha...
# 4   https://dev.to/qingkouwei/swiper-style-waterfl...
# 5   https://dev.to/aloe/arkui-xtong-guo-stagemo-xi...
# 6   https://dev.to/sidtalesara/arc-browser-is-dead...
# 7   https://dev.to/qingkouwei/pixel-unit-conversio...
# 8   https://dev.to/qingkouwei/page-parameter-passi...
# 9                https://dev.to/thestorybookdev/-3ci7
# 10  https://dev.to/joe111/introducing-neo-ui-mui-i...
# 11  https://dev.to/ramunarasinga-11/remeda-package...
# 12  https://dev.to/asim786521/why-udp-powers-strea...
# 13  https://dev.to/ruuma_fb53ad7177cba32d962/nuxt-...
# 14  https://dev.to/1suleyman/what-is-serverless-co...
# 15  https://dev.to/noorsimar/from-500-lines-to-150...
# 16  https://dev.to/aloe/arkui-xkuang-jia-loginterf...
# 17  https://dev.to/gail_axelrod_03844667f64d/we-ga...
# 18  https://dev.to/devopsfundamentals/machine-lear...
# 19  https://dev.to/aloe/arkui-xgou-jian-androidpin...
# 20  https://dev.to/aloe/arkui-xzai-androidshang-sh...
# 21  https://dev.to/hoangquochung1110/bo-sung-ngu-c...
# 22  https://dev.to/carrie_luo1/safeline-waf-high-a...
# 23  https://dev.to/aloe/arkui-xping-tai-chai-yi-hu...
# 24  https://dev.to/sgchris/using-phantomdata-and-z...

# %%
#merge 2 dataframe
merge_df = pd.merge(df, article_df, on = 'Link', how='inner')
merge_df
# Out:
#                                                  Link  \
# 0   https://dev.to/qingkouwei/nested-class-state-o...
# 1   https://dev.to/qingkouwei/intercepting-touch-e...
# 2   https://dev.to/qingkouwei/using-semi-modal-in-...
# 3   https://dev.to/qingkouwei/text-content-font-ha...
# 4   https://dev.to/qingkouwei/swiper-style-waterfl...
# 5   https://dev.to/aloe/arkui-xtong-guo-stagemo-xi...
# 6   https://dev.to/sidtalesara/arc-browser-is-dead...
# 7   https://dev.to/qingkouwei/pixel-unit-conversio...
# 8   https://dev.to/qingkouwei/page-parameter-passi...
# 9                https://dev.to/thestorybookdev/-3ci7
# 10  https://dev.to/joe111/introducing-neo-ui-mui-i...
# 11  https://dev.to/ramunarasinga-11/remeda-package...
# 12  https://dev.to/asim786521/why-udp-powers-strea...
# 13  https://dev.to/ruuma_fb53ad7177cba32d962/nuxt-...
# 14  https://dev.to/1suleyman/what-is-serverless-co...
# 15  https://dev.to/noorsimar/from-500-lines-to-150...
# 16  https://dev.to/aloe/arkui-xkuang-jia-loginterf...
# 17  https://dev.to/gail_axelrod_03844667f64d/we-ga...
# 18  https://dev.to/devopsfundamentals/machine-lear...
# 19  https://dev.to/aloe/arkui-xgou-jian-androidpin...
# 20  https://dev.to/aloe/arkui-xzai-androidshang-sh...
# 21  https://dev.to/hoangquochung1110/bo-sung-ngu-c...
# 22  https://dev.to/carrie_luo1/safeline-waf-high-a...
# 23  https://dev.to/aloe/arkui-xping-tai-chai-yi-hu...
# 24  https://dev.to/sgchris/using-phantomdata-and-z...
#
#                                                 Title         Time_Uploaded  \
# 0   Nested Class State Observation, Text & Emoji D...  2025-06-25T15:55:42Z
# 1   Intercepting Touch Events, Disabling Side Swip...  2025-06-25T15:54:13Z
# 2   Using Semi-modal in Lists, Custom Toast, Popup...  2025-06-25T15:52:29Z
# 3   Text Content Font, Half-screen Routing, Input ...  2025-06-25T15:51:06Z
# 4   Swiper Style, WaterFlow, Clipboard, Manual Tra...  2025-06-25T15:49:43Z
# 5                   ArkUI-X通过Stage模型开发Android端应用指南(二)  2025-06-25T15:48:48Z
# 6   Arc Browser is Dead, and Dia Isn’t the Answer:...  2025-06-25T15:48:35Z
# 7   Pixel Unit Conversion, Dialog Declaration Issu...  2025-06-25T15:48:05Z
# 8   Page Parameter Passing, Popup Disable Blank Cl...  2025-06-25T15:46:07Z
# 9                                             [Boost]  2025-06-25T15:45:49Z
# 10  Introducing Neo UI – MUI-Inspired Component Li...  2025-06-25T15:42:39Z
# 11                remeda package in 0.email codebase.  2025-06-25T15:30:00Z
# 12  Why UDP Powers Streaming, Gaming, and Real-Tim...  2025-06-25T15:22:53Z
# 13  Nuxt 3 + Google OAuth (PKCE) Minimal Setup Gui...  2025-06-25T15:22:48Z
# 14  ☁️ What Is Serverless Computing? (And Why It’s...  2025-06-25T15:22:37Z
# 15  From 500+ Lines to 150: How I Refactored My Am...  2025-06-25T15:22:09Z
# 16                          ArkUI-X框架LogInterface使用指南  2025-06-25T15:19:15Z
# 17    We Gave Our Engineers AI. Here's What Happened.  2025-06-25T15:19:14Z
# 18  Machine Learning Fundamentals: active learning...  2025-06-25T15:17:43Z
# 19                           ArkUI-X构建Android平台AAR及使用  2025-06-25T15:15:48Z
# 20                     ArkUI-X在Android上使用Fragment开发指南  2025-06-25T15:14:07Z
# 21  Bổ sung ngữ cảnh cho LLM: Nâng cao độ chính xá...  2025-06-25T15:13:22Z
# 22            SafeLine WAF High Availability Solution  2025-06-25T15:11:41Z
# 23                                       ArkUI-X平台差异化  2025-06-25T15:10:42Z
# 24             Using PhantomData and Zero-Sized Types  2025-06-25T15:10:22Z
#
#                Authors                                         Tags  \
# 0          kouwei qing                               #harmonyosnext
# 1          kouwei qing                               #harmonyosnext
# 2          kouwei qing                               #harmonyosnext
# 3          kouwei qing                               #harmonyosnext
# 4          kouwei qing                               #harmonyosnext
# 5                  龙儿筝
# 6   Siddharth Talesara          #ai #openai #playwright #automation
# 7          kouwei qing                               #harmonyosnext
# 8          kouwei qing                               #harmonyosnext
# 9        Shalom Mathew                #kubernetes #aws #eks #awseks
# 10       Joe Moussally             #reactnative #mui #react #mobile
# 11      Ramu Narasinga              #zero #email #react #opensource
# 12          Asim786521                  #udp #streaming #atprotocol
# 13               ruuma               #nuxt #vue #oauth #googlecloud
# 14           1suleyman        #aws #cloud #beginners #documentation
# 15     Noorsimar Singh      #webscraping #scrapy #scrapeops #python
# 16                 龙儿筝
# 17        Gail Axelrod                            #ai #productivity
# 18  DevOps Fundamental  #machinelearning #ai #activelearningproject
# 19                 龙儿筝
# 20                 龙儿筝
# 21     Quoc-Hung Hoang
# 22              Carrie                 #ha #waf #safeline #security
# 23                 龙儿筝
# 24       Gregory Chris       #programming #rust #learning #tutorial
#
#    Reading_Time                                    Article_Content
# 0    4 min read  How to observe the state change of field3 in C...
# 1    3 min read  When nesting a Scroll component within a page,...
# 2    4 min read  There is a sharing popup-like page that needs ...
# 3    3 min read  To globally use custom fonts in an app, regist...
# 4    2 min read  When setting code in Swiper to control both th...
# 5    3 min read  StageApplication初始化支持以下三种方式 public class HiSta...
# 6    5 min read  When The Browser Company announced Arc, it fel...
# 7    3 min read  The UI provides an image with 750 pixels. When...
# 8    3 min read  How to pass parameters to WindowContent throug...
# 9    1 min read
# 10   1 min read  Hey folks 👋 After building multiple products w...
# 11   4 min read  In this article, we will review remeda package...
# 12   2 min read  UDP stands for User Datagram Protocol. It is o...
# 13   3 min read  ✍  Originally published in Japanese on Qiita, ...
# 14   3 min read  Hey everyone 👋 If you’ve been getting into clo...
# 15   4 min read  Like many developers, I started Amazon scrapin...
# 16   1 min read  ArkUI-X框架支持日志拦截能力，Android侧提供原生接口，用于注入LogInterf...
# 17   3 min read  By Eli Daniel, Head of Engineering, Jellyfish ...
# 18   6 min read  In Q3 2023, a critical fraud detection model a...
# 19   1 min read  本教程主要讲述如何利用ArkUI-X SDK完成Android AAR开发，实现基于ArkT...
# 20   2 min read  本文介绍将ArkUI框架的UIAbility跨平台部署至Android平台Fragment的...
# 21  10 min read  Các Mô hình Ngôn ngữ Lớn (LLM) là những công c...
# 22   4 min read  The SafeLine WAF High Availability solution en...
# 23   1 min read  跨平台使用场景是一套ArkTS代码运行在多个终端设备上，如Android、iOS、OpenH...
# 24   4 min read  Rust is a language that thrives on safety and ...

# %%
import nltk
from nltk.corpus import stopwords
from nltk.sentiment.vader import SentimentIntensityAnalyzer

#Download the stopword datasets
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('vader_lexicon')
nltk.download('punket_tab')

def count_words_without_stopwords(text):
    if isinstance(text,(str,bytes)):
        words = nltk.word_tokenize(str(text))
        stop_words = set(stopwords.words('english'))
        filtered_words = [word for word in words if word.lower() not in stop_words ]
        return  len(filtered_words)  
    else:
        0
        
merge_df ['Word_Count']  = merge_df ['Article_Content'].apply(count_words_without_stopwords)  
merge_df
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\feven/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to C:\Users\feven/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\feven/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\feven/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Error loading punket_tab: Package 'punket_tab' not found
# [nltk_data]     in index
# C:\Users\feven\AppData\Local\Temp\ipykernel_5072\2736232535.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merge_df ['Word_Count']  = merge_df ['Article_Content'].apply(count_words_without_stopwords)
#                                                  Link  \
# 0   https://dev.to/qingkouwei/nested-class-state-o...
# 1   https://dev.to/qingkouwei/intercepting-touch-e...
# 2   https://dev.to/qingkouwei/using-semi-modal-in-...
# 3   https://dev.to/qingkouwei/text-content-font-ha...
# 4   https://dev.to/qingkouwei/swiper-style-waterfl...
# 6   https://dev.to/sidtalesara/arc-browser-is-dead...
# 7   https://dev.to/qingkouwei/pixel-unit-conversio...
# 8   https://dev.to/qingkouwei/page-parameter-passi...
# 9                https://dev.to/thestorybookdev/-3ci7
# 10  https://dev.to/joe111/introducing-neo-ui-mui-i...
# 11  https://dev.to/ramunarasinga-11/remeda-package...
# 12  https://dev.to/asim786521/why-udp-powers-strea...
# 13  https://dev.to/ruuma_fb53ad7177cba32d962/nuxt-...
# 14  https://dev.to/1suleyman/what-is-serverless-co...
# 15  https://dev.to/noorsimar/from-500-lines-to-150...
# 17  https://dev.to/gail_axelrod_03844667f64d/we-ga...
# 18  https://dev.to/devopsfundamentals/machine-lear...
# 22  https://dev.to/carrie_luo1/safeline-waf-high-a...
# 24  https://dev.to/sgchris/using-phantomdata-and-z...
#
#                                                 Title         Time_Uploaded  \
# 0   Nested Class State Observation, Text & Emoji D...  2025-06-25T15:55:42Z
# 1   Intercepting Touch Events, Disabling Side Swip...  2025-06-25T15:54:13Z
# 2   Using Semi-modal in Lists, Custom Toast, Popup...  2025-06-25T15:52:29Z
# 3   Text Content Font, Half-screen Routing, Input ...  2025-06-25T15:51:06Z
# 4   Swiper Style, WaterFlow, Clipboard, Manual Tra...  2025-06-25T15:49:43Z
# 6   Arc Browser is Dead, and Dia Isn’t the Answer:...  2025-06-25T15:48:35Z
# 7   Pixel Unit Conversion, Dialog Declaration Issu...  2025-06-25T15:48:05Z
# 8   Page Parameter Passing, Popup Disable Blank Cl...  2025-06-25T15:46:07Z
# 9                                             [Boost]  2025-06-25T15:45:49Z
# 10  Introducing Neo UI – MUI-Inspired Component Li...  2025-06-25T15:42:39Z
# 11                remeda package in 0.email codebase.  2025-06-25T15:30:00Z
# 12  Why UDP Powers Streaming, Gaming, and Real-Tim...  2025-06-25T15:22:53Z
# 13  Nuxt 3 + Google OAuth (PKCE) Minimal Setup Gui...  2025-06-25T15:22:48Z
# 14  ☁️ What Is Serverless Computing? (And Why It’s...  2025-06-25T15:22:37Z
# 15  From 500+ Lines to 150: How I Refactored My Am...  2025-06-25T15:22:09Z
# 17    We Gave Our Engineers AI. Here's What Happened.  2025-06-25T15:19:14Z
# 18  Machine Learning Fundamentals: active learning...  2025-06-25T15:17:43Z
# 22            SafeLine WAF High Availability Solution  2025-06-25T15:11:41Z
# 24             Using PhantomData and Zero-Sized Types  2025-06-25T15:10:22Z
#
#                Authors                                         Tags  \
# 0          kouwei qing                               #harmonyosnext
# 1          kouwei qing                               #harmonyosnext
# 2          kouwei qing                               #harmonyosnext
# 3          kouwei qing                               #harmonyosnext
# 4          kouwei qing                               #harmonyosnext
# 6   Siddharth Talesara          #ai #openai #playwright #automation
# 7          kouwei qing                               #harmonyosnext
# 8          kouwei qing                               #harmonyosnext
# 9        Shalom Mathew                #kubernetes #aws #eks #awseks
# 10       Joe Moussally             #reactnative #mui #react #mobile
# 11      Ramu Narasinga              #zero #email #react #opensource
# 12          Asim786521                  #udp #streaming #atprotocol
# 13               ruuma               #nuxt #vue #oauth #googlecloud
# 14           1suleyman        #aws #cloud #beginners #documentation
# 15     Noorsimar Singh      #webscraping #scrapy #scrapeops #python
# 17        Gail Axelrod                            #ai #productivity
# 18  DevOps Fundamental  #machinelearning #ai #activelearningproject
# 22              Carrie                 #ha #waf #safeline #security
# 24       Gregory Chris       #programming #rust #learning #tutorial
#
#     Reading_Time                                    Article_Content  \
# 0              4  How to observe the state change of field3 in C...
# 1              3  When nesting a Scroll component within a page,...
# 2              4  There is a sharing popup-like page that needs ...
# 3              3  To globally use custom fonts in an app, regist...
# 4              2  When setting code in Swiper to control both th...
# 6              5  When The Browser Company announced Arc, it fel...
# 7              3  The UI provides an image with 750 pixels. When...
# 8              3  How to pass parameters to WindowContent throug...
# 9              1
# 10             1  Hey folks 👋 After building multiple products w...
# 11             4  In this article, we will review remeda package...
# 12             2  UDP stands for User Datagram Protocol. It is o...
# 13             3  ✍  Originally published in Japanese on Qiita, ...
# 14             3  Hey everyone 👋 If you’ve been getting into clo...
# 15             4  Like many developers, I started Amazon scrapin...
# 17             3  By Eli Daniel, Head of Engineering, Jellyfish ...
# 18             6  In Q3 2023, a critical fraud detection model a...
# 22             4  The SafeLine WAF High Availability solution en...
# 24             4  Rust is a language that thrives on safety and ...
#
#     Word_Count Sentiment  Compound_Score Language
# 0          482  Positive          0.8253  English
# 1          269  Positive          0.8253  English
# 2          226  Positive          0.8253  English
# 3          263  Positive          0.8253  English
# 4          188  Positive          0.8253  English
# 6          767  Positive          0.8253  English
# 7          222  Positive          0.8253  English
# 8          256  Positive          0.8253  English
# 9            0  Positive          0.8253  English
# 10         143  Positive          0.8253  English
# 11         355  Positive          0.8253  English
# 12         205  Positive          0.8253  English
# 13          86  Positive          0.8253  English
# 14         355  Positive          0.8253  English
# 15         254  Positive          0.8253  English
# 17         457  Positive          0.8253  English
# 18         793  Positive          0.8253  English
# 22         396  Positive          0.8253  English
# 24         501  Positive          0.8253  English

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import pandas as pd
sid = SentimentIntensityAnalyzer()

def get_sentiment(row):
    
    sentiment_scores = sid.polarity_scores(merge_df.Article_Content[20])
    compound_score = sentiment_scores['compound']

    if compound_score >= 0.05:
      sentiment = 'Positive'
    elif compound_score <=  -0.05:
      sentiment = 'Negative'
    else:
      sentiment = 'Neutral' 
     
    return sentiment , compound_score   
         
#df[['Sentiment' , 'Compound_Score']] = df['Article_Content'].astype(str).apply(lambda x: pd.Series(get_sentiment(x)))
merge_df[['Sentiment', 'Compound_Score']] = merge_df['Article_Content'].astype(str).apply( lambda x: pd.Series(get_sentiment(x)))   
merge_df
# Out:
#                                                  Link  \
# 0   https://dev.to/qingkouwei/nested-class-state-o...
# 1   https://dev.to/qingkouwei/intercepting-touch-e...
# 2   https://dev.to/qingkouwei/using-semi-modal-in-...
# 3   https://dev.to/qingkouwei/text-content-font-ha...
# 4   https://dev.to/qingkouwei/swiper-style-waterfl...
# 5   https://dev.to/aloe/arkui-xtong-guo-stagemo-xi...
# 6   https://dev.to/sidtalesara/arc-browser-is-dead...
# 7   https://dev.to/qingkouwei/pixel-unit-conversio...
# 8   https://dev.to/qingkouwei/page-parameter-passi...
# 9                https://dev.to/thestorybookdev/-3ci7
# 10  https://dev.to/joe111/introducing-neo-ui-mui-i...
# 11  https://dev.to/ramunarasinga-11/remeda-package...
# 12  https://dev.to/asim786521/why-udp-powers-strea...
# 13  https://dev.to/ruuma_fb53ad7177cba32d962/nuxt-...
# 14  https://dev.to/1suleyman/what-is-serverless-co...
# 15  https://dev.to/noorsimar/from-500-lines-to-150...
# 16  https://dev.to/aloe/arkui-xkuang-jia-loginterf...
# 17  https://dev.to/gail_axelrod_03844667f64d/we-ga...
# 18  https://dev.to/devopsfundamentals/machine-lear...
# 19  https://dev.to/aloe/arkui-xgou-jian-androidpin...
# 20  https://dev.to/aloe/arkui-xzai-androidshang-sh...
# 21  https://dev.to/hoangquochung1110/bo-sung-ngu-c...
# 22  https://dev.to/carrie_luo1/safeline-waf-high-a...
# 23  https://dev.to/aloe/arkui-xping-tai-chai-yi-hu...
# 24  https://dev.to/sgchris/using-phantomdata-and-z...
#
#                                                 Title         Time_Uploaded  \
# 0   Nested Class State Observation, Text & Emoji D...  2025-06-25T15:55:42Z
# 1   Intercepting Touch Events, Disabling Side Swip...  2025-06-25T15:54:13Z
# 2   Using Semi-modal in Lists, Custom Toast, Popup...  2025-06-25T15:52:29Z
# 3   Text Content Font, Half-screen Routing, Input ...  2025-06-25T15:51:06Z
# 4   Swiper Style, WaterFlow, Clipboard, Manual Tra...  2025-06-25T15:49:43Z
# 5                   ArkUI-X通过Stage模型开发Android端应用指南(二)  2025-06-25T15:48:48Z
# 6   Arc Browser is Dead, and Dia Isn’t the Answer:...  2025-06-25T15:48:35Z
# 7   Pixel Unit Conversion, Dialog Declaration Issu...  2025-06-25T15:48:05Z
# 8   Page Parameter Passing, Popup Disable Blank Cl...  2025-06-25T15:46:07Z
# 9                                             [Boost]  2025-06-25T15:45:49Z
# 10  Introducing Neo UI – MUI-Inspired Component Li...  2025-06-25T15:42:39Z
# 11                remeda package in 0.email codebase.  2025-06-25T15:30:00Z
# 12  Why UDP Powers Streaming, Gaming, and Real-Tim...  2025-06-25T15:22:53Z
# 13  Nuxt 3 + Google OAuth (PKCE) Minimal Setup Gui...  2025-06-25T15:22:48Z
# 14  ☁️ What Is Serverless Computing? (And Why It’s...  2025-06-25T15:22:37Z
# 15  From 500+ Lines to 150: How I Refactored My Am...  2025-06-25T15:22:09Z
# 16                          ArkUI-X框架LogInterface使用指南  2025-06-25T15:19:15Z
# 17    We Gave Our Engineers AI. Here's What Happened.  2025-06-25T15:19:14Z
# 18  Machine Learning Fundamentals: active learning...  2025-06-25T15:17:43Z
# 19                           ArkUI-X构建Android平台AAR及使用  2025-06-25T15:15:48Z
# 20                     ArkUI-X在Android上使用Fragment开发指南  2025-06-25T15:14:07Z
# 21  Bổ sung ngữ cảnh cho LLM: Nâng cao độ chính xá...  2025-06-25T15:13:22Z
# 22            SafeLine WAF High Availability Solution  2025-06-25T15:11:41Z
# 23                                       ArkUI-X平台差异化  2025-06-25T15:10:42Z
# 24             Using PhantomData and Zero-Sized Types  2025-06-25T15:10:22Z
#
#                Authors                                         Tags  \
# 0          kouwei qing                               #harmonyosnext
# 1          kouwei qing                               #harmonyosnext
# 2          kouwei qing                               #harmonyosnext
# 3          kouwei qing                               #harmonyosnext
# 4          kouwei qing                               #harmonyosnext
# 5                  龙儿筝
# 6   Siddharth Talesara          #ai #openai #playwright #automation
# 7          kouwei qing                               #harmonyosnext
# 8          kouwei qing                               #harmonyosnext
# 9        Shalom Mathew                #kubernetes #aws #eks #awseks
# 10       Joe Moussally             #reactnative #mui #react #mobile
# 11      Ramu Narasinga              #zero #email #react #opensource
# 12          Asim786521                  #udp #streaming #atprotocol
# 13               ruuma               #nuxt #vue #oauth #googlecloud
# 14           1suleyman        #aws #cloud #beginners #documentation
# 15     Noorsimar Singh      #webscraping #scrapy #scrapeops #python
# 16                 龙儿筝
# 17        Gail Axelrod                            #ai #productivity
# 18  DevOps Fundamental  #machinelearning #ai #activelearningproject
# 19                 龙儿筝
# 20                 龙儿筝
# 21     Quoc-Hung Hoang
# 22              Carrie                 #ha #waf #safeline #security
# 23                 龙儿筝
# 24       Gregory Chris       #programming #rust #learning #tutorial
#
#    Reading_Time                                    Article_Content  \
# 0    4 min read  How to observe the state change of field3 in C...
# 1    3 min read  When nesting a Scroll component within a page,...
# 2    4 min read  There is a sharing popup-like page that needs ...
# 3    3 min read  To globally use custom fonts in an app, regist...
# 4    2 min read  When setting code in Swiper to control both th...
# 5    3 min read  StageApplication初始化支持以下三种方式 public class HiSta...
# 6    5 min read  When The Browser Company announced Arc, it fel...
# 7    3 min read  The UI provides an image with 750 pixels. When...
# 8    3 min read  How to pass parameters to WindowContent throug...
# 9    1 min read
# 10   1 min read  Hey folks 👋 After building multiple products w...
# 11   4 min read  In this article, we will review remeda package...
# 12   2 min read  UDP stands for User Datagram Protocol. It is o...
# 13   3 min read  ✍  Originally published in Japanese on Qiita, ...
# 14   3 min read  Hey everyone 👋 If you’ve been getting into clo...
# 15   4 min read  Like many developers, I started Amazon scrapin...
# 16   1 min read  ArkUI-X框架支持日志拦截能力，Android侧提供原生接口，用于注入LogInterf...
# 17   3 min read  By Eli Daniel, Head of Engineering, Jellyfish ...
# 18   6 min read  In Q3 2023, a critical fraud detection model a...
# 19   1 min read  本教程主要讲述如何利用ArkUI-X SDK完成Android AAR开发，实现基于ArkT...
# 20   2 min read  本文介绍将ArkUI框架的UIAbility跨平台部署至Android平台Fragment的...
# 21  10 min read  Các Mô hình Ngôn ngữ Lớn (LLM) là những công c...
# 22   4 min read  The SafeLine WAF High Availability solution en...
# 23   1 min read  跨平台使用场景是一套ArkTS代码运行在多个终端设备上，如Android、iOS、OpenH...
# 24   4 min read  Rust is a language that thrives on safety and ...
#
#     Word_Count Sentiment  Compound_Score
# 0          482  Positive          0.8253
# 1          269  Positive          0.8253
# 2          226  Positive          0.8253
# 3          263  Positive          0.8253
# 4          188  Positive          0.8253
# 5          750  Positive          0.8253
# 6          767  Positive          0.8253
# 7          222  Positive          0.8253
# 8          256  Positive          0.8253
# 9            0  Positive          0.8253
# 10         143  Positive          0.8253
# 11         355  Positive          0.8253
# 12         205  Positive          0.8253
# 13          86  Positive          0.8253
# 14         355  Positive          0.8253
# 15         254  Positive          0.8253
# 16         108  Positive          0.8253
# 17         457  Positive          0.8253
# 18         793  Positive          0.8253
# 19         193  Positive          0.8253
# 20         298  Positive          0.8253
# 21        1806  Positive          0.8253
# 22         396  Positive          0.8253
# 23         272  Positive          0.8253
# 24         501  Positive          0.8253

# %%
import pandas as pd 
import langid
import pycountry

def detect_language(text) :
    # conver NAN to an empty string
    text = str(text) if pd.notna(text) else ''
    
    # use langid to detect the language
    lang, confidence = langid.classify(text)
    return lang
merge_df['Language'] =merge_df['Article_Content'].apply(detect_language)
merge_df['Language']=merge_df['Language'].map(lambda code: pycountry.languages.get(alpha_2=code).name if pycountry.languages.get(alpha_2=code) else code)

merge_df = merge_df[merge_df['Language'] == 'English']
merge_df['Reading_Time'] = merge_df['Reading_Time'].astype(str).str.replace(' min read', '', regex=False).str.strip().replace('', '0').astype(int)

    
merge_df
# Out:
# C:\Users\feven\AppData\Local\Temp\ipykernel_5072\227734844.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merge_df['Reading_Time'] = merge_df['Reading_Time'].astype(str).str.replace(' min read', '', regex=False).str.strip().replace('', '0').astype(int)
#                                                  Link  \
# 0   https://dev.to/qingkouwei/nested-class-state-o...
# 1   https://dev.to/qingkouwei/intercepting-touch-e...
# 2   https://dev.to/qingkouwei/using-semi-modal-in-...
# 3   https://dev.to/qingkouwei/text-content-font-ha...
# 4   https://dev.to/qingkouwei/swiper-style-waterfl...
# 6   https://dev.to/sidtalesara/arc-browser-is-dead...
# 7   https://dev.to/qingkouwei/pixel-unit-conversio...
# 8   https://dev.to/qingkouwei/page-parameter-passi...
# 9                https://dev.to/thestorybookdev/-3ci7
# 10  https://dev.to/joe111/introducing-neo-ui-mui-i...
# 11  https://dev.to/ramunarasinga-11/remeda-package...
# 12  https://dev.to/asim786521/why-udp-powers-strea...
# 13  https://dev.to/ruuma_fb53ad7177cba32d962/nuxt-...
# 14  https://dev.to/1suleyman/what-is-serverless-co...
# 15  https://dev.to/noorsimar/from-500-lines-to-150...
# 17  https://dev.to/gail_axelrod_03844667f64d/we-ga...
# 18  https://dev.to/devopsfundamentals/machine-lear...
# 22  https://dev.to/carrie_luo1/safeline-waf-high-a...
# 24  https://dev.to/sgchris/using-phantomdata-and-z...
#
#                                                 Title         Time_Uploaded  \
# 0   Nested Class State Observation, Text & Emoji D...  2025-06-25T15:55:42Z
# 1   Intercepting Touch Events, Disabling Side Swip...  2025-06-25T15:54:13Z
# 2   Using Semi-modal in Lists, Custom Toast, Popup...  2025-06-25T15:52:29Z
# 3   Text Content Font, Half-screen Routing, Input ...  2025-06-25T15:51:06Z
# 4   Swiper Style, WaterFlow, Clipboard, Manual Tra...  2025-06-25T15:49:43Z
# 6   Arc Browser is Dead, and Dia Isn’t the Answer:...  2025-06-25T15:48:35Z
# 7   Pixel Unit Conversion, Dialog Declaration Issu...  2025-06-25T15:48:05Z
# 8   Page Parameter Passing, Popup Disable Blank Cl...  2025-06-25T15:46:07Z
# 9                                             [Boost]  2025-06-25T15:45:49Z
# 10  Introducing Neo UI – MUI-Inspired Component Li...  2025-06-25T15:42:39Z
# 11                remeda package in 0.email codebase.  2025-06-25T15:30:00Z
# 12  Why UDP Powers Streaming, Gaming, and Real-Tim...  2025-06-25T15:22:53Z
# 13  Nuxt 3 + Google OAuth (PKCE) Minimal Setup Gui...  2025-06-25T15:22:48Z
# 14  ☁️ What Is Serverless Computing? (And Why It’s...  2025-06-25T15:22:37Z
# 15  From 500+ Lines to 150: How I Refactored My Am...  2025-06-25T15:22:09Z
# 17    We Gave Our Engineers AI. Here's What Happened.  2025-06-25T15:19:14Z
# 18  Machine Learning Fundamentals: active learning...  2025-06-25T15:17:43Z
# 22            SafeLine WAF High Availability Solution  2025-06-25T15:11:41Z
# 24             Using PhantomData and Zero-Sized Types  2025-06-25T15:10:22Z
#
#                Authors                                         Tags  \
# 0          kouwei qing                               #harmonyosnext
# 1          kouwei qing                               #harmonyosnext
# 2          kouwei qing                               #harmonyosnext
# 3          kouwei qing                               #harmonyosnext
# 4          kouwei qing                               #harmonyosnext
# 6   Siddharth Talesara          #ai #openai #playwright #automation
# 7          kouwei qing                               #harmonyosnext
# 8          kouwei qing                               #harmonyosnext
# 9        Shalom Mathew                #kubernetes #aws #eks #awseks
# 10       Joe Moussally             #reactnative #mui #react #mobile
# 11      Ramu Narasinga              #zero #email #react #opensource
# 12          Asim786521                  #udp #streaming #atprotocol
# 13               ruuma               #nuxt #vue #oauth #googlecloud
# 14           1suleyman        #aws #cloud #beginners #documentation
# 15     Noorsimar Singh      #webscraping #scrapy #scrapeops #python
# 17        Gail Axelrod                            #ai #productivity
# 18  DevOps Fundamental  #machinelearning #ai #activelearningproject
# 22              Carrie                 #ha #waf #safeline #security
# 24       Gregory Chris       #programming #rust #learning #tutorial
#
#     Reading_Time                                    Article_Content  \
# 0              4  How to observe the state change of field3 in C...
# 1              3  When nesting a Scroll component within a page,...
# 2              4  There is a sharing popup-like page that needs ...
# 3              3  To globally use custom fonts in an app, regist...
# 4              2  When setting code in Swiper to control both th...
# 6              5  When The Browser Company announced Arc, it fel...
# 7              3  The UI provides an image with 750 pixels. When...
# 8              3  How to pass parameters to WindowContent throug...
# 9              1
# 10             1  Hey folks 👋 After building multiple products w...
# 11             4  In this article, we will review remeda package...
# 12             2  UDP stands for User Datagram Protocol. It is o...
# 13             3  ✍  Originally published in Japanese on Qiita, ...
# 14             3  Hey everyone 👋 If you’ve been getting into clo...
# 15             4  Like many developers, I started Amazon scrapin...
# 17             3  By Eli Daniel, Head of Engineering, Jellyfish ...
# 18             6  In Q3 2023, a critical fraud detection model a...
# 22             4  The SafeLine WAF High Availability solution en...
# 24             4  Rust is a language that thrives on safety and ...
#
#     Word_Count Sentiment  Compound_Score Language
# 0          482  Positive          0.8253  English
# 1          269  Positive          0.8253  English
# 2          226  Positive          0.8253  English
# 3          263  Positive          0.8253  English
# 4          188  Positive          0.8253  English
# 6          767  Positive          0.8253  English
# 7          222  Positive          0.8253  English
# 8          256  Positive          0.8253  English
# 9            0  Positive          0.8253  English
# 10         143  Positive          0.8253  English
# 11         355  Positive          0.8253  English
# 12         205  Positive          0.8253  English
# 13          86  Positive          0.8253  English
# 14         355  Positive          0.8253  English
# 15         254  Positive          0.8253  English
# 17         457  Positive          0.8253  English
# 18         793  Positive          0.8253  English
# 22         396  Positive          0.8253  English
# 24         501  Positive          0.8253  English

# %%
#CREATE TABLE IF NOT EXISTS  article
#(
 #   Link Text Primary Key,
#	Title Text,
#	Time_Uploaded TIMESTAMP,
#	Authors Text,
#	Tags Text,
#	Reading_Time Integer,
#	Article_Content Text,
#	Word_Count Integer,
#	Sentiment Text,
#	Compound_Score Numeric,
#	Language Text
#	);

# %%
import psycopg2
db_parms = {
    "dbname": "postgres" ,
    "user": os.getenv("DB_USER") ,
    "password" :os.getenv("DB_PASSWORD"),
    "host" : os.getenv("DB_HOST"),
    "port" :"5432"
}
conn = None
try:
    #connect to postgreSQL
    conn = psycopg2.connect (**db_parms)
    cursor = conn.cursor()
    
    #sql insert query
    insert_query ="""
    Insert Into articles (Link, Title, Time_Uploaded, Authors, Tags, Reading_Time, Article_Content ,Word_Count, Sentiment, Compound_Score, Language )
    Values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
    ON CONFLICT (Link) DO NOTHING
    """
    
    # insert DataFrame records one by one
    for _, row in merge_df.iterrows():
        cursor.execute(insert_query,(
            row['Link'], row['Title'],row['Time_Uploaded'] ,row['Authors'], row['Tags'], row['Reading_Time'],
            row['Article_Content'],row['Word_Count'],row['Sentiment'], row['Compound_Score'],row['Language']
        ))
        
    #commit 
    conn.commit()   
    print ("Data inserted successfully!")

except Exception as e:
    print(e)
    
finally:
    if conn:
        cursor.close () 
        conn.close ()
# Out:
# connection to server at "localhost" (::1), port 5432 failed: Connection refused (0x0000274D/10061)
# 	Is the server running on that host and accepting TCP/IP connections?
# connection to server at "localhost" (127.0.0.1), port 5432 failed: Connection refused (0x0000274D/10061)
# 	Is the server running on that host and accepting TCP/IP connections?

# %%
print("Total rows in merge_df:", len(merge_df))
# Out:
# Total rows in merge_df: 19
