# %%
#pip install requests pandas fake_useragent bs4 langid pycountry nltk

# %%
import  requests
from bs4 import BeautifulSoup
from fake_useragent import UserAgent #used to create fake user inorder for requests
import pandas as pd
import os

url = 'https://dev.to/latest'

ua=UserAgent()
userAgent= ua.random
headers= {'User_Agent': userAgent}
page = requests.get(url, headers = headers)
soup= BeautifulSoup(page.content,'html.parser')

# %%
blog_box = soup.find_all('div' ,'crayons-story')

links = [] 
titles = [] 
time_uploaded = []  
authors = []
tags = []
reading_times = []


for box in blog_box:
    #links
    if box.find('h2', class_ = 'crayons-story__title') is not None:
        link =  box.find('h2', class_ = 'crayons-story__title').a
        link = link['href']
        links.append(link)
    else:
        links.append('None')  
        
    #titles    
    if box.find('h2', class_ = 'crayons-story__title') is not None:
        title =  box.find('h2', class_ = 'crayons-story__title')
        titles.append(title.text.replace('\n','').strip())
    else:
        titles.append('None')          

    #time_uploaded 
    if box.find('time', attrs={'datetime': True}) is not None:
        time_upload =  box.find('time', attrs={'datetime': True})
        time_upload= time_upload['datetime']
        time_uploaded.append (time_upload)
    else:
        time_uploaded.append('None') 

    #authors 
    if box.find('a', class_ = 'crayons-story__secondary fw-medium m:hidden') is not None:
        author =  box.find('a', class_ = 'crayons-story__secondary fw-medium m:hidden')
        authors.append(author.text.replace('\n','').strip())
    else:
        authors.append('None')  


    #tags  
    if box.find('div', class_ = 'crayons-story__tags') is not None:
        tag =  box.find('div', class_ = 'crayons-story__tags')
        tags.append(tag.text.replace('\n',' ').strip())
    else:
        tags.append('None')
        
 #reading_time  
    if box.find('div', class_ = 'crayons-story__save') is not None:
        reading_time  =  box.find('div', class_ = 'crayons-story__save')
        reading_times.append(reading_time.text.replace('\n',' ').strip())
    else:
        reading_times.append('None')  
  
  
df = pd.DataFrame(
    {
    'Link' : links,
    'Title' : titles,
    'Time_Uploaded' : time_uploaded ,
    'Authors' : authors,
    'Tags' : tags,
    'Reading_Time' : reading_times
    }
) 

df= df[ df['Link'] != 'None']

df
# Out:
#                                                  Link  \
# 2   https://dev.to/analaura/quando-foi-que-a-gente...
# 3   https://dev.to/neuml/medical-rag-research-with...
# 4   https://dev.to/learnspringtools/springbootfirs...
# 5   https://dev.to/learnspringtools/springbootfirs...
# 6   https://dev.to/learnspringtools/springbootfirs...
# 7   https://dev.to/vaib/declarative-programming-sq...
# 8   https://dev.to/nabbisen/uiux-da-gui-mo-na-css-...
# 9   https://dev.to/mia_koring_962598adda4663/text-...
# 10        https://dev.to/fangmbeng/cyberguard-ai-107i
# 11  https://dev.to/sigurdurb/build-a-sanctions-che...
# 12  https://dev.to/teruxz/devops-kak-po-uchiebniku...
# 13  https://dev.to/huetteldorf/announcing-pyseoa-t...
# 14  https://dev.to/codanyks/stop-duct-taping-conte...
# 15  https://dev.to/motchan/why-ai-keeps-butchering...
# 16  https://dev.to/surrealdb/databases-are-the-nex...
# 17  https://dev.to/pythonxi/building-a-web-based-e...
# 18  https://dev.to/cxrtisxl/tlsnotary-flow-overvie...
# 19  https://dev.to/navashub/content-generator-from...
# 20  https://dev.to/teruxz/orghanizatsiia-iac-modul...
# 21  https://dev.to/kireji/a-space-age-metaphor-for...
# 22  https://dev.to/freedom_coder/cve-2023-20198-ci...
# 23                  https://dev.to/vincenttommi/-3d6o
# 24  https://dev.to/msnmongare/how-long-does-it-tak...
# 25  https://dev.to/devopsfundamentals/big-data-fun...
# 26  https://dev.to/vaib/building-ethical-ai-a-prac...
#
#                                                 Title         Time_Uploaded  \
# 2    Quando foi que a gente parou de fazer perguntas?  2025-06-23T21:23:06Z
# 3                     Medical RAG Research with txtai  2025-06-23T21:23:43Z
# 4                           springboot.firststeps(P1)  2025-06-23T21:06:55Z
# 5                           springboot.firststeps(P2)  2025-06-23T21:06:38Z
# 6                          springboot.firststeps(lib)  2025-06-23T21:05:23Z
# 7   Declarative Programming: SQL, HTML, CSS, Prolo...  2025-06-23T21:02:36Z
# 8                               UI/UX - 大規模な CSS への対応  2025-06-23T21:00:00Z
# 9   Text Compressing Introduction - Huffman Coding...  2025-06-23T20:49:39Z
# 10                                      CyberGuard AI  2025-06-23T20:46:48Z
# 11  Build a sanctions check in 10 minutes with San...  2025-06-23T20:40:26Z
# 12          DevOps как по учебнику. Возможно ли? [RU]  2025-06-23T20:39:51Z
# 13  Announcing pyseoa-ts v0.2.0 – More Power, More...  2025-06-23T20:35:48Z
# 14  Stop Duct-Taping Context Into Prompts: Meet th...  2025-06-23T20:35:00Z
# 15  "Why AI Keeps Butchering Your Designs (And How...  2025-06-23T20:34:23Z
# 16                 Databases Are the Next AI Frontier  2025-06-23T20:33:15Z
# 17  Building a Web-Based Excel Editor: A Comprehen...  2025-06-23T20:31:46Z
# 18                          TLSNotary ― Flow Overview  2025-06-23T20:28:17Z
# 19            Content Generator from youtube video id  2025-06-23T20:26:05Z
# 20                      Организация IaC: Модули. [RU]  2025-06-23T20:25:04Z
# 21      A Space-Age Metaphor for Software Development  2025-06-23T20:22:06Z
# 22  CVE-2023-20198: Cisco IOS XE Web UI Privilege ...  2025-06-23T20:20:12Z
# 23                              Every developers Read  2025-06-23T20:16:18Z
# 24  How Long Does It Take to Understand the Basics...  2025-06-23T20:13:02Z
# 25           Big Data Fundamentals: big data tutorial  2025-06-23T20:11:45Z
# 26  Building Ethical AI: A Practical Guide to Resp...  2025-06-23T20:01:59Z
#
#                Authors                                              Tags  \
# 2            Ana Laura
# 3       David Mezzetti                     #ai #llm #rag #vectordatabase
# 4           olver team
# 5           olver team
# 6           olver team
# 7               Vaiber            #programming #declarative #sql #prolog
# 8             nabbisen                         #vue #webdev #design #css
# 9           Mia Koring    #computerscience #algorithms #swift #beginners
# 10      Brandon Atonte
# 11          Sigurdur B                 #api #fintech #compliance #python
# 12     Anton Streltsov                #discuss #devops #culture #russian
# 13            sempre76             #webdev #seo #typescript #programming
# 14            Codanyks                       #ai #mcp #programming #node
# 15              Edna N
# 16          Mark Gyles
# 17        Augustus otu      #webdev #programming #javascript #typescript
# 18         Ian Sosunov          #cryptography #blockchain #privacy #tlsn
# 19       Navas Herbert
# 20     Anton Streltsov                #terraform #devops #russian #howto
# 21  Eric Augustinowicz   #multiverse #metaphor #development #datascience
# 22       Freedom Coder  #cisco #iosxewebui #cybersecurity #vulnerability
# 23       Vincent Tommi     #beginners #programming #productivity #webdev
# 24   Sospeter Mong'are     #beginners #programming #productivity #webdev
# 25  DevOps Fundamental  #bigdata #dataengineering #data #bigdatatutorial
# 26              Vaiber            #ai #machinelearning #python #tutorial
#
#    Reading_Time
# 2    1 min read
# 3    7 min read
# 4    3 min read
# 5    4 min read
# 6    5 min read
# 7    7 min read
# 8    1 min read
# 9    1 min read
# 10   4 min read
# 11   2 min read
# 12   1 min read
# 13   1 min read
# 14   5 min read
# 15   1 min read
# 16   2 min read
# 17  17 min read
# 18   2 min read
# 19   4 min read
# 20   1 min read
# 21   3 min read
# 22   2 min read
# 23   1 min read
# 24   2 min read
# 25   5 min read
# 26   7 min read

# %%
##Second_url = 'https://dev.to/sejdi_gashi/live-and-online-our-food-waste-reduction-platform-is-almost-ready-5dfi'
article = []
article_link = []

def get_full_content (Second_url):
    ua=UserAgent()
    userAgent= ua.random
    headers= {'User_Agent': userAgent}
    page = requests.get(Second_url, headers = headers)
    soup= BeautifulSoup(page.content,'html.parser')
    print(Second_url)

    content = soup.find ('div',class_='crayons-article__main')
    paragrphs = content.find_all('p')

    contents = []
    for i in paragrphs:
        contents.append(i.text.replace('\n',' '))
    
    string  = ' '.join(contents)
    article.append (string)
    article_link.append(Second_url)

for i in df.Link:
    get_full_content(i)
article_df = pd.DataFrame(
      {
      'Article_Content' : article,
      'Link' : article_link
      }
    )

article_df
# Out:
# https://dev.to/analaura/quando-foi-que-a-gente-parou-de-fazer-perguntas-45hc
# https://dev.to/neuml/medical-rag-research-with-txtai-2b35
# https://dev.to/learnspringtools/springbootfirststepsp1-56na
# https://dev.to/learnspringtools/springbootfirststepsp2-4o52
# https://dev.to/learnspringtools/springbootfirststepslib-54ki
# https://dev.to/vaib/declarative-programming-sql-html-css-prolog-guide-nd0
# https://dev.to/nabbisen/uiux-da-gui-mo-na-css-henodui-ying-3563
# https://dev.to/mia_koring_962598adda4663/text-compressing-introduction-huffman-coding-in-swift-1o97
# https://dev.to/fangmbeng/cyberguard-ai-107i
# https://dev.to/sigurdurb/build-a-sanctions-check-in-10-minutes-with-sanctionsnap-api-4moh
# https://dev.to/teruxz/devops-kak-po-uchiebniku-vozmozhno-li-ru-3jnb
# https://dev.to/huetteldorf/announcing-pyseoa-ts-v020-more-power-more-control-49ji
# https://dev.to/codanyks/stop-duct-taping-context-into-prompts-meet-the-mcp-server-hi5
# https://dev.to/motchan/why-ai-keeps-butchering-your-designs-and-how-i-fixed-it-3f19
# https://dev.to/surrealdb/databases-are-the-next-ai-frontier-156j
# https://dev.to/pythonxi/building-a-web-based-excel-editor-a-comprehensive-guide-2p4b
# https://dev.to/cxrtisxl/tlsnotary-flow-overview-17o0
# https://dev.to/navashub/content-generator-from-youtube-video-id-3j6j
# https://dev.to/teruxz/orghanizatsiia-iac-moduli-ru-4klc
# https://dev.to/kireji/a-space-age-metaphor-for-software-development-3pie
# https://dev.to/freedom_coder/cve-2023-20198-cisco-ios-xe-web-ui-privilege-escalation-vulnerability-3jk3
# https://dev.to/vincenttommi/-3d6o
# https://dev.to/msnmongare/how-long-does-it-take-to-understand-the-basics-of-a-new-programming-language-5748
# https://dev.to/devopsfundamentals/big-data-fundamentals-big-data-tutorial-4l62
# https://dev.to/vaib/building-ethical-ai-a-practical-guide-to-responsible-development-lad
#                                       Article_Content  \
# 0   Hey, Vsauce. Michael here Alguns meses, descob...
# 1   txtai is an all-in-one AI framework for semant...
# 2    personaController.java  @DateTimeFormat(patte...
# 3    peliculaController.java  pelicula.jsp  pelicu...
# 4   libroControlador.java  loginController.java  l...
# 5   Welcome, fellow developers and curious minds! ...
# 6   大規模なスタイルセットを記述する場合、CSS では限界があります。そこで登場するのが、CSS...
# 7   Ever wondered how file compression actually wo...
# 8   The cybersecurity landscape is facing an unpre...
# 9   Goal: show you how to screen names against glo...
# 10  DevOps —  это не отдельная роль, а скорее фило...
# 11  We're excited to release pyseoa-ts v0.2.0, a T...
# 12  If you’ve ever built anything slightly more co...
# 13  A visual-first layout system that treats the i...
# 14  Author: Tobie Morgan Hitchcock This blog post ...
# 15  By the Toki Space Team Building a fully-featur...
# 16  Working on Bring ID I've dived into the TLSNot...
# 17  An AI-powered content generation tool that cre...
# 18  Недавно, на личном опыте столкнулся с тем, что...
# 19  Captain's Log, supplemental. Metaphors are a u...
# 20  CVE-2023-20198 Cisco IOS XE Web UI Privilege E...
# 21
# 22  From the perspective of a senior software engi...
# 23  The relentless growth of data presents a const...
# 24  The rapid advancement and pervasive integratio...
#
#                                                  Link
# 0   https://dev.to/analaura/quando-foi-que-a-gente...
# 1   https://dev.to/neuml/medical-rag-research-with...
# 2   https://dev.to/learnspringtools/springbootfirs...
# 3   https://dev.to/learnspringtools/springbootfirs...
# 4   https://dev.to/learnspringtools/springbootfirs...
# 5   https://dev.to/vaib/declarative-programming-sq...
# 6   https://dev.to/nabbisen/uiux-da-gui-mo-na-css-...
# 7   https://dev.to/mia_koring_962598adda4663/text-...
# 8         https://dev.to/fangmbeng/cyberguard-ai-107i
# 9   https://dev.to/sigurdurb/build-a-sanctions-che...
# 10  https://dev.to/teruxz/devops-kak-po-uchiebniku...
# 11  https://dev.to/huetteldorf/announcing-pyseoa-t...
# 12  https://dev.to/codanyks/stop-duct-taping-conte...
# 13  https://dev.to/motchan/why-ai-keeps-butchering...
# 14  https://dev.to/surrealdb/databases-are-the-nex...
# 15  https://dev.to/pythonxi/building-a-web-based-e...
# 16  https://dev.to/cxrtisxl/tlsnotary-flow-overvie...
# 17  https://dev.to/navashub/content-generator-from...
# 18  https://dev.to/teruxz/orghanizatsiia-iac-modul...
# 19  https://dev.to/kireji/a-space-age-metaphor-for...
# 20  https://dev.to/freedom_coder/cve-2023-20198-ci...
# 21                  https://dev.to/vincenttommi/-3d6o
# 22  https://dev.to/msnmongare/how-long-does-it-tak...
# 23  https://dev.to/devopsfundamentals/big-data-fun...
# 24  https://dev.to/vaib/building-ethical-ai-a-prac...

# %%
#merge 2 dataframe
merge_df = pd.merge(df, article_df, on = 'Link', how='inner')
merge_df
# Out:
#                                                  Link  \
# 0   https://dev.to/analaura/quando-foi-que-a-gente...
# 1   https://dev.to/neuml/medical-rag-research-with...
# 2   https://dev.to/learnspringtools/springbootfirs...
# 3   https://dev.to/learnspringtools/springbootfirs...
# 4   https://dev.to/learnspringtools/springbootfirs...
# 5   https://dev.to/vaib/declarative-programming-sq...
# 6   https://dev.to/nabbisen/uiux-da-gui-mo-na-css-...
# 7   https://dev.to/mia_koring_962598adda4663/text-...
# 8         https://dev.to/fangmbeng/cyberguard-ai-107i
# 9   https://dev.to/sigurdurb/build-a-sanctions-che...
# 10  https://dev.to/teruxz/devops-kak-po-uchiebniku...
# 11  https://dev.to/huetteldorf/announcing-pyseoa-t...
# 12  https://dev.to/codanyks/stop-duct-taping-conte...
# 13  https://dev.to/motchan/why-ai-keeps-butchering...
# 14  https://dev.to/surrealdb/databases-are-the-nex...
# 15  https://dev.to/pythonxi/building-a-web-based-e...
# 16  https://dev.to/cxrtisxl/tlsnotary-flow-overvie...
# 17  https://dev.to/navashub/content-generator-from...
# 18  https://dev.to/teruxz/orghanizatsiia-iac-modul...
# 19  https://dev.to/kireji/a-space-age-metaphor-for...
# 20  https://dev.to/freedom_coder/cve-2023-20198-ci...
# 21                  https://dev.to/vincenttommi/-3d6o
# 22  https://dev.to/msnmongare/how-long-does-it-tak...
# 23  https://dev.to/devopsfundamentals/big-data-fun...
# 24  https://dev.to/vaib/building-ethical-ai-a-prac...
#
#                                                 Title         Time_Uploaded  \
# 0    Quando foi que a gente parou de fazer perguntas?  2025-06-23T21:23:06Z
# 1                     Medical RAG Research with txtai  2025-06-23T21:23:43Z
# 2                           springboot.firststeps(P1)  2025-06-23T21:06:55Z
# 3                           springboot.firststeps(P2)  2025-06-23T21:06:38Z
# 4                          springboot.firststeps(lib)  2025-06-23T21:05:23Z
# 5   Declarative Programming: SQL, HTML, CSS, Prolo...  2025-06-23T21:02:36Z
# 6                               UI/UX - 大規模な CSS への対応  2025-06-23T21:00:00Z
# 7   Text Compressing Introduction - Huffman Coding...  2025-06-23T20:49:39Z
# 8                                       CyberGuard AI  2025-06-23T20:46:48Z
# 9   Build a sanctions check in 10 minutes with San...  2025-06-23T20:40:26Z
# 10          DevOps как по учебнику. Возможно ли? [RU]  2025-06-23T20:39:51Z
# 11  Announcing pyseoa-ts v0.2.0 – More Power, More...  2025-06-23T20:35:48Z
# 12  Stop Duct-Taping Context Into Prompts: Meet th...  2025-06-23T20:35:00Z
# 13  "Why AI Keeps Butchering Your Designs (And How...  2025-06-23T20:34:23Z
# 14                 Databases Are the Next AI Frontier  2025-06-23T20:33:15Z
# 15  Building a Web-Based Excel Editor: A Comprehen...  2025-06-23T20:31:46Z
# 16                          TLSNotary ― Flow Overview  2025-06-23T20:28:17Z
# 17            Content Generator from youtube video id  2025-06-23T20:26:05Z
# 18                      Организация IaC: Модули. [RU]  2025-06-23T20:25:04Z
# 19      A Space-Age Metaphor for Software Development  2025-06-23T20:22:06Z
# 20  CVE-2023-20198: Cisco IOS XE Web UI Privilege ...  2025-06-23T20:20:12Z
# 21                              Every developers Read  2025-06-23T20:16:18Z
# 22  How Long Does It Take to Understand the Basics...  2025-06-23T20:13:02Z
# 23           Big Data Fundamentals: big data tutorial  2025-06-23T20:11:45Z
# 24  Building Ethical AI: A Practical Guide to Resp...  2025-06-23T20:01:59Z
#
#                Authors                                              Tags  \
# 0            Ana Laura
# 1       David Mezzetti                     #ai #llm #rag #vectordatabase
# 2           olver team
# 3           olver team
# 4           olver team
# 5               Vaiber            #programming #declarative #sql #prolog
# 6             nabbisen                         #vue #webdev #design #css
# 7           Mia Koring    #computerscience #algorithms #swift #beginners
# 8       Brandon Atonte
# 9           Sigurdur B                 #api #fintech #compliance #python
# 10     Anton Streltsov                #discuss #devops #culture #russian
# 11            sempre76             #webdev #seo #typescript #programming
# 12            Codanyks                       #ai #mcp #programming #node
# 13              Edna N
# 14          Mark Gyles
# 15        Augustus otu      #webdev #programming #javascript #typescript
# 16         Ian Sosunov          #cryptography #blockchain #privacy #tlsn
# 17       Navas Herbert
# 18     Anton Streltsov                #terraform #devops #russian #howto
# 19  Eric Augustinowicz   #multiverse #metaphor #development #datascience
# 20       Freedom Coder  #cisco #iosxewebui #cybersecurity #vulnerability
# 21       Vincent Tommi     #beginners #programming #productivity #webdev
# 22   Sospeter Mong'are     #beginners #programming #productivity #webdev
# 23  DevOps Fundamental  #bigdata #dataengineering #data #bigdatatutorial
# 24              Vaiber            #ai #machinelearning #python #tutorial
#
#    Reading_Time                                    Article_Content
# 0    1 min read  Hey, Vsauce. Michael here Alguns meses, descob...
# 1    7 min read  txtai is an all-in-one AI framework for semant...
# 2    3 min read   personaController.java  @DateTimeFormat(patte...
# 3    4 min read   peliculaController.java  pelicula.jsp  pelicu...
# 4    5 min read  libroControlador.java  loginController.java  l...
# 5    7 min read  Welcome, fellow developers and curious minds! ...
# 6    1 min read  大規模なスタイルセットを記述する場合、CSS では限界があります。そこで登場するのが、CSS...
# 7    1 min read  Ever wondered how file compression actually wo...
# 8    4 min read  The cybersecurity landscape is facing an unpre...
# 9    2 min read  Goal: show you how to screen names against glo...
# 10   1 min read  DevOps —  это не отдельная роль, а скорее фило...
# 11   1 min read  We're excited to release pyseoa-ts v0.2.0, a T...
# 12   5 min read  If you’ve ever built anything slightly more co...
# 13   1 min read  A visual-first layout system that treats the i...
# 14   2 min read  Author: Tobie Morgan Hitchcock This blog post ...
# 15  17 min read  By the Toki Space Team Building a fully-featur...
# 16   2 min read  Working on Bring ID I've dived into the TLSNot...
# 17   4 min read  An AI-powered content generation tool that cre...
# 18   1 min read  Недавно, на личном опыте столкнулся с тем, что...
# 19   3 min read  Captain's Log, supplemental. Metaphors are a u...
# 20   2 min read  CVE-2023-20198 Cisco IOS XE Web UI Privilege E...
# 21   1 min read
# 22   2 min read  From the perspective of a senior software engi...
# 23   5 min read  The relentless growth of data presents a const...
# 24   7 min read  The rapid advancement and pervasive integratio...

# %%
from nltk.corpus import stopwords
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

#Download the stopword datasets
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('vader_lexicon')
nltk.download('punket_tab')

def count_words_without_stopwords(text):
    if isinstance(text,(str,bytes)):
        words = nltk.word_tokenize(str(text))
        stop_words = set(stopwords.words('english'))
        filtered_words = [word for word in words if word.lower() not in stop_words ]
        return  len(filtered_words)  
    else:
        0
        
merge_df ['Word_Count']  = merge_df ['Article_Content'].apply(count_words_without_stopwords)  
merge_df
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\feven/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to C:\Users\feven/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\feven/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\feven/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Error loading punket_tab: Package 'punket_tab' not found
# [nltk_data]     in index
#                                                  Link  \
# 0   https://dev.to/analaura/quando-foi-que-a-gente...
# 1   https://dev.to/neuml/medical-rag-research-with...
# 2   https://dev.to/learnspringtools/springbootfirs...
# 3   https://dev.to/learnspringtools/springbootfirs...
# 4   https://dev.to/learnspringtools/springbootfirs...
# 5   https://dev.to/vaib/declarative-programming-sq...
# 6   https://dev.to/nabbisen/uiux-da-gui-mo-na-css-...
# 7   https://dev.to/mia_koring_962598adda4663/text-...
# 8         https://dev.to/fangmbeng/cyberguard-ai-107i
# 9   https://dev.to/sigurdurb/build-a-sanctions-che...
# 10  https://dev.to/teruxz/devops-kak-po-uchiebniku...
# 11  https://dev.to/huetteldorf/announcing-pyseoa-t...
# 12  https://dev.to/codanyks/stop-duct-taping-conte...
# 13  https://dev.to/motchan/why-ai-keeps-butchering...
# 14  https://dev.to/surrealdb/databases-are-the-nex...
# 15  https://dev.to/pythonxi/building-a-web-based-e...
# 16  https://dev.to/cxrtisxl/tlsnotary-flow-overvie...
# 17  https://dev.to/navashub/content-generator-from...
# 18  https://dev.to/teruxz/orghanizatsiia-iac-modul...
# 19  https://dev.to/kireji/a-space-age-metaphor-for...
# 20  https://dev.to/freedom_coder/cve-2023-20198-ci...
# 21                  https://dev.to/vincenttommi/-3d6o
# 22  https://dev.to/msnmongare/how-long-does-it-tak...
# 23  https://dev.to/devopsfundamentals/big-data-fun...
# 24  https://dev.to/vaib/building-ethical-ai-a-prac...
#
#                                                 Title         Time_Uploaded  \
# 0    Quando foi que a gente parou de fazer perguntas?  2025-06-23T21:23:06Z
# 1                     Medical RAG Research with txtai  2025-06-23T21:23:43Z
# 2                           springboot.firststeps(P1)  2025-06-23T21:06:55Z
# 3                           springboot.firststeps(P2)  2025-06-23T21:06:38Z
# 4                          springboot.firststeps(lib)  2025-06-23T21:05:23Z
# 5   Declarative Programming: SQL, HTML, CSS, Prolo...  2025-06-23T21:02:36Z
# 6                               UI/UX - 大規模な CSS への対応  2025-06-23T21:00:00Z
# 7   Text Compressing Introduction - Huffman Coding...  2025-06-23T20:49:39Z
# 8                                       CyberGuard AI  2025-06-23T20:46:48Z
# 9   Build a sanctions check in 10 minutes with San...  2025-06-23T20:40:26Z
# 10          DevOps как по учебнику. Возможно ли? [RU]  2025-06-23T20:39:51Z
# 11  Announcing pyseoa-ts v0.2.0 – More Power, More...  2025-06-23T20:35:48Z
# 12  Stop Duct-Taping Context Into Prompts: Meet th...  2025-06-23T20:35:00Z
# 13  "Why AI Keeps Butchering Your Designs (And How...  2025-06-23T20:34:23Z
# 14                 Databases Are the Next AI Frontier  2025-06-23T20:33:15Z
# 15  Building a Web-Based Excel Editor: A Comprehen...  2025-06-23T20:31:46Z
# 16                          TLSNotary ― Flow Overview  2025-06-23T20:28:17Z
# 17            Content Generator from youtube video id  2025-06-23T20:26:05Z
# 18                      Организация IaC: Модули. [RU]  2025-06-23T20:25:04Z
# 19      A Space-Age Metaphor for Software Development  2025-06-23T20:22:06Z
# 20  CVE-2023-20198: Cisco IOS XE Web UI Privilege ...  2025-06-23T20:20:12Z
# 21                              Every developers Read  2025-06-23T20:16:18Z
# 22  How Long Does It Take to Understand the Basics...  2025-06-23T20:13:02Z
# 23           Big Data Fundamentals: big data tutorial  2025-06-23T20:11:45Z
# 24  Building Ethical AI: A Practical Guide to Resp...  2025-06-23T20:01:59Z
#
#                Authors                                              Tags  \
# 0            Ana Laura
# 1       David Mezzetti                     #ai #llm #rag #vectordatabase
# 2           olver team
# 3           olver team
# 4           olver team
# 5               Vaiber            #programming #declarative #sql #prolog
# 6             nabbisen                         #vue #webdev #design #css
# 7           Mia Koring    #computerscience #algorithms #swift #beginners
# 8       Brandon Atonte
# 9           Sigurdur B                 #api #fintech #compliance #python
# 10     Anton Streltsov                #discuss #devops #culture #russian
# 11            sempre76             #webdev #seo #typescript #programming
# 12            Codanyks                       #ai #mcp #programming #node
# 13              Edna N
# 14          Mark Gyles
# 15        Augustus otu      #webdev #programming #javascript #typescript
# 16         Ian Sosunov          #cryptography #blockchain #privacy #tlsn
# 17       Navas Herbert
# 18     Anton Streltsov                #terraform #devops #russian #howto
# 19  Eric Augustinowicz   #multiverse #metaphor #development #datascience
# 20       Freedom Coder  #cisco #iosxewebui #cybersecurity #vulnerability
# 21       Vincent Tommi     #beginners #programming #productivity #webdev
# 22   Sospeter Mong'are     #beginners #programming #productivity #webdev
# 23  DevOps Fundamental  #bigdata #dataengineering #data #bigdatatutorial
# 24              Vaiber            #ai #machinelearning #python #tutorial
#
#    Reading_Time                                    Article_Content  Word_Count
# 0    1 min read  Hey, Vsauce. Michael here Alguns meses, descob...         133
# 1    7 min read  txtai is an all-in-one AI framework for semant...         458
# 2    3 min read   personaController.java  @DateTimeFormat(patte...          22
# 3    4 min read   peliculaController.java  pelicula.jsp  pelicu...           9
# 4    5 min read  libroControlador.java  loginController.java  l...           7
# 5    7 min read  Welcome, fellow developers and curious minds! ...         666
# 6    1 min read  大規模なスタイルセットを記述する場合、CSS では限界があります。そこで登場するのが、CSS...          43
# 7    1 min read  Ever wondered how file compression actually wo...         111
# 8    4 min read  The cybersecurity landscape is facing an unpre...         717
# 9    2 min read  Goal: show you how to screen names against glo...          51
# 10   1 min read  DevOps —  это не отдельная роль, а скорее фило...        1655
# 11   1 min read  We're excited to release pyseoa-ts v0.2.0, a T...          65
# 12   5 min read  If you’ve ever built anything slightly more co...         675
# 13   1 min read  A visual-first layout system that treats the i...          61
# 14   2 min read  Author: Tobie Morgan Hitchcock This blog post ...         311
# 15  17 min read  By the Toki Space Team Building a fully-featur...         847
# 16   2 min read  Working on Bring ID I've dived into the TLSNot...         203
# 17   4 min read  An AI-powered content generation tool that cre...         114
# 18   1 min read  Недавно, на личном опыте столкнулся с тем, что...         565
# 19   3 min read  Captain's Log, supplemental. Metaphors are a u...         424
# 20   2 min read  CVE-2023-20198 Cisco IOS XE Web UI Privilege E...         101
# 21   1 min read                                                              0
# 22   2 min read  From the perspective of a senior software engi...         241
# 23   5 min read  The relentless growth of data presents a const...         489
# 24   7 min read  The rapid advancement and pervasive integratio...         451

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import pandas as pd
sid = SentimentIntensityAnalyzer()

def get_sentiment(row):
    
    sentiment_scores = sid.polarity_scores(merge_df.Article_Content[20])
    compound_score = sentiment_scores['compound']

    if compound_score >= 0.05:
      sentiment = 'Positive'
    elif compound_score <=  -0.05:
      sentiment = 'Negative'
    else:
      sentiment = 'Neutral' 
     
    return sentiment , compound_score   
         
#df[['Sentiment' , 'Compound_Score']] = df['Article_Content'].astype(str).apply(lambda x: pd.Series(get_sentiment(x)))
merge_df[['Sentiment', 'Compound_Score']] = merge_df['Article_Content'].astype(str).apply( lambda x: pd.Series(get_sentiment(x)))   
merge_df
# Out:
#                                                  Link  \
# 0   https://dev.to/analaura/quando-foi-que-a-gente...
# 1   https://dev.to/neuml/medical-rag-research-with...
# 2   https://dev.to/learnspringtools/springbootfirs...
# 3   https://dev.to/learnspringtools/springbootfirs...
# 4   https://dev.to/learnspringtools/springbootfirs...
# 5   https://dev.to/vaib/declarative-programming-sq...
# 6   https://dev.to/nabbisen/uiux-da-gui-mo-na-css-...
# 7   https://dev.to/mia_koring_962598adda4663/text-...
# 8         https://dev.to/fangmbeng/cyberguard-ai-107i
# 9   https://dev.to/sigurdurb/build-a-sanctions-che...
# 10  https://dev.to/teruxz/devops-kak-po-uchiebniku...
# 11  https://dev.to/huetteldorf/announcing-pyseoa-t...
# 12  https://dev.to/codanyks/stop-duct-taping-conte...
# 13  https://dev.to/motchan/why-ai-keeps-butchering...
# 14  https://dev.to/surrealdb/databases-are-the-nex...
# 15  https://dev.to/pythonxi/building-a-web-based-e...
# 16  https://dev.to/cxrtisxl/tlsnotary-flow-overvie...
# 17  https://dev.to/navashub/content-generator-from...
# 18  https://dev.to/teruxz/orghanizatsiia-iac-modul...
# 19  https://dev.to/kireji/a-space-age-metaphor-for...
# 20  https://dev.to/freedom_coder/cve-2023-20198-ci...
# 21                  https://dev.to/vincenttommi/-3d6o
# 22  https://dev.to/msnmongare/how-long-does-it-tak...
# 23  https://dev.to/devopsfundamentals/big-data-fun...
# 24  https://dev.to/vaib/building-ethical-ai-a-prac...
#
#                                                 Title         Time_Uploaded  \
# 0    Quando foi que a gente parou de fazer perguntas?  2025-06-23T21:23:06Z
# 1                     Medical RAG Research with txtai  2025-06-23T21:23:43Z
# 2                           springboot.firststeps(P1)  2025-06-23T21:06:55Z
# 3                           springboot.firststeps(P2)  2025-06-23T21:06:38Z
# 4                          springboot.firststeps(lib)  2025-06-23T21:05:23Z
# 5   Declarative Programming: SQL, HTML, CSS, Prolo...  2025-06-23T21:02:36Z
# 6                               UI/UX - 大規模な CSS への対応  2025-06-23T21:00:00Z
# 7   Text Compressing Introduction - Huffman Coding...  2025-06-23T20:49:39Z
# 8                                       CyberGuard AI  2025-06-23T20:46:48Z
# 9   Build a sanctions check in 10 minutes with San...  2025-06-23T20:40:26Z
# 10          DevOps как по учебнику. Возможно ли? [RU]  2025-06-23T20:39:51Z
# 11  Announcing pyseoa-ts v0.2.0 – More Power, More...  2025-06-23T20:35:48Z
# 12  Stop Duct-Taping Context Into Prompts: Meet th...  2025-06-23T20:35:00Z
# 13  "Why AI Keeps Butchering Your Designs (And How...  2025-06-23T20:34:23Z
# 14                 Databases Are the Next AI Frontier  2025-06-23T20:33:15Z
# 15  Building a Web-Based Excel Editor: A Comprehen...  2025-06-23T20:31:46Z
# 16                          TLSNotary ― Flow Overview  2025-06-23T20:28:17Z
# 17            Content Generator from youtube video id  2025-06-23T20:26:05Z
# 18                      Организация IaC: Модули. [RU]  2025-06-23T20:25:04Z
# 19      A Space-Age Metaphor for Software Development  2025-06-23T20:22:06Z
# 20  CVE-2023-20198: Cisco IOS XE Web UI Privilege ...  2025-06-23T20:20:12Z
# 21                              Every developers Read  2025-06-23T20:16:18Z
# 22  How Long Does It Take to Understand the Basics...  2025-06-23T20:13:02Z
# 23           Big Data Fundamentals: big data tutorial  2025-06-23T20:11:45Z
# 24  Building Ethical AI: A Practical Guide to Resp...  2025-06-23T20:01:59Z
#
#                Authors                                              Tags  \
# 0            Ana Laura
# 1       David Mezzetti                     #ai #llm #rag #vectordatabase
# 2           olver team
# 3           olver team
# 4           olver team
# 5               Vaiber            #programming #declarative #sql #prolog
# 6             nabbisen                         #vue #webdev #design #css
# 7           Mia Koring    #computerscience #algorithms #swift #beginners
# 8       Brandon Atonte
# 9           Sigurdur B                 #api #fintech #compliance #python
# 10     Anton Streltsov                #discuss #devops #culture #russian
# 11            sempre76             #webdev #seo #typescript #programming
# 12            Codanyks                       #ai #mcp #programming #node
# 13              Edna N
# 14          Mark Gyles
# 15        Augustus otu      #webdev #programming #javascript #typescript
# 16         Ian Sosunov          #cryptography #blockchain #privacy #tlsn
# 17       Navas Herbert
# 18     Anton Streltsov                #terraform #devops #russian #howto
# 19  Eric Augustinowicz   #multiverse #metaphor #development #datascience
# 20       Freedom Coder  #cisco #iosxewebui #cybersecurity #vulnerability
# 21       Vincent Tommi     #beginners #programming #productivity #webdev
# 22   Sospeter Mong'are     #beginners #programming #productivity #webdev
# 23  DevOps Fundamental  #bigdata #dataengineering #data #bigdatatutorial
# 24              Vaiber            #ai #machinelearning #python #tutorial
#
#    Reading_Time                                    Article_Content  \
# 0    1 min read  Hey, Vsauce. Michael here Alguns meses, descob...
# 1    7 min read  txtai is an all-in-one AI framework for semant...
# 2    3 min read   personaController.java  @DateTimeFormat(patte...
# 3    4 min read   peliculaController.java  pelicula.jsp  pelicu...
# 4    5 min read  libroControlador.java  loginController.java  l...
# 5    7 min read  Welcome, fellow developers and curious minds! ...
# 6    1 min read  大規模なスタイルセットを記述する場合、CSS では限界があります。そこで登場するのが、CSS...
# 7    1 min read  Ever wondered how file compression actually wo...
# 8    4 min read  The cybersecurity landscape is facing an unpre...
# 9    2 min read  Goal: show you how to screen names against glo...
# 10   1 min read  DevOps —  это не отдельная роль, а скорее фило...
# 11   1 min read  We're excited to release pyseoa-ts v0.2.0, a T...
# 12   5 min read  If you’ve ever built anything slightly more co...
# 13   1 min read  A visual-first layout system that treats the i...
# 14   2 min read  Author: Tobie Morgan Hitchcock This blog post ...
# 15  17 min read  By the Toki Space Team Building a fully-featur...
# 16   2 min read  Working on Bring ID I've dived into the TLSNot...
# 17   4 min read  An AI-powered content generation tool that cre...
# 18   1 min read  Недавно, на личном опыте столкнулся с тем, что...
# 19   3 min read  Captain's Log, supplemental. Metaphors are a u...
# 20   2 min read  CVE-2023-20198 Cisco IOS XE Web UI Privilege E...
# 21   1 min read
# 22   2 min read  From the perspective of a senior software engi...
# 23   5 min read  The relentless growth of data presents a const...
# 24   7 min read  The rapid advancement and pervasive integratio...
#
#     Word_Count Sentiment  Compound_Score
# 0          133  Positive          0.4939
# 1          458  Positive          0.4939
# 2           22  Positive          0.4939
# 3            9  Positive          0.4939
# 4            7  Positive          0.4939
# 5          666  Positive          0.4939
# 6           43  Positive          0.4939
# 7          111  Positive          0.4939
# 8          717  Positive          0.4939
# 9           51  Positive          0.4939
# 10        1655  Positive          0.4939
# 11          65  Positive          0.4939
# 12         675  Positive          0.4939
# 13          61  Positive          0.4939
# 14         311  Positive          0.4939
# 15         847  Positive          0.4939
# 16         203  Positive          0.4939
# 17         114  Positive          0.4939
# 18         565  Positive          0.4939
# 19         424  Positive          0.4939
# 20         101  Positive          0.4939
# 21           0  Positive          0.4939
# 22         241  Positive          0.4939
# 23         489  Positive          0.4939
# 24         451  Positive          0.4939

# %%
import pandas as pd 
import langid
import pycountry

def detect_language(text) :
    # conver NAN to an empty string
    text = str(text) if pd.notna(text) else ''
    
    # use langid to detect the language
    lang, confidence = langid.classify(text)
    return lang
merge_df['Language'] =merge_df['Article_Content'].apply(detect_language)
merge_df['Language']=merge_df['Language'].map(lambda code: pycountry.languages.get(alpha_2=code).name if pycountry.languages.get(alpha_2=code) else code)

merge_df = merge_df[merge_df['Language'] == 'English']
merge_df['Reading_Time'] = merge_df['Reading_Time'].astype(str).str.replace(' min read', '', regex=False).str.strip().replace('', '0').astype(int)

    
merge_df
# Out:
# C:\Users\feven\AppData\Local\Temp\ipykernel_29188\227734844.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merge_df['Reading_Time'] = merge_df['Reading_Time'].astype(str).str.replace(' min read', '', regex=False).str.strip().replace('', '0').astype(int)
#                                                  Link  \
# 1   https://dev.to/neuml/medical-rag-research-with...
# 2   https://dev.to/learnspringtools/springbootfirs...
# 5   https://dev.to/vaib/declarative-programming-sq...
# 7   https://dev.to/mia_koring_962598adda4663/text-...
# 8         https://dev.to/fangmbeng/cyberguard-ai-107i
# 9   https://dev.to/sigurdurb/build-a-sanctions-che...
# 11  https://dev.to/huetteldorf/announcing-pyseoa-t...
# 12  https://dev.to/codanyks/stop-duct-taping-conte...
# 13  https://dev.to/motchan/why-ai-keeps-butchering...
# 14  https://dev.to/surrealdb/databases-are-the-nex...
# 15  https://dev.to/pythonxi/building-a-web-based-e...
# 16  https://dev.to/cxrtisxl/tlsnotary-flow-overvie...
# 17  https://dev.to/navashub/content-generator-from...
# 19  https://dev.to/kireji/a-space-age-metaphor-for...
# 20  https://dev.to/freedom_coder/cve-2023-20198-ci...
# 21                  https://dev.to/vincenttommi/-3d6o
# 22  https://dev.to/msnmongare/how-long-does-it-tak...
# 23  https://dev.to/devopsfundamentals/big-data-fun...
# 24  https://dev.to/vaib/building-ethical-ai-a-prac...
#
#                                                 Title         Time_Uploaded  \
# 1                     Medical RAG Research with txtai  2025-06-23T21:23:43Z
# 2                           springboot.firststeps(P1)  2025-06-23T21:06:55Z
# 5   Declarative Programming: SQL, HTML, CSS, Prolo...  2025-06-23T21:02:36Z
# 7   Text Compressing Introduction - Huffman Coding...  2025-06-23T20:49:39Z
# 8                                       CyberGuard AI  2025-06-23T20:46:48Z
# 9   Build a sanctions check in 10 minutes with San...  2025-06-23T20:40:26Z
# 11  Announcing pyseoa-ts v0.2.0 – More Power, More...  2025-06-23T20:35:48Z
# 12  Stop Duct-Taping Context Into Prompts: Meet th...  2025-06-23T20:35:00Z
# 13  "Why AI Keeps Butchering Your Designs (And How...  2025-06-23T20:34:23Z
# 14                 Databases Are the Next AI Frontier  2025-06-23T20:33:15Z
# 15  Building a Web-Based Excel Editor: A Comprehen...  2025-06-23T20:31:46Z
# 16                          TLSNotary ― Flow Overview  2025-06-23T20:28:17Z
# 17            Content Generator from youtube video id  2025-06-23T20:26:05Z
# 19      A Space-Age Metaphor for Software Development  2025-06-23T20:22:06Z
# 20  CVE-2023-20198: Cisco IOS XE Web UI Privilege ...  2025-06-23T20:20:12Z
# 21                              Every developers Read  2025-06-23T20:16:18Z
# 22  How Long Does It Take to Understand the Basics...  2025-06-23T20:13:02Z
# 23           Big Data Fundamentals: big data tutorial  2025-06-23T20:11:45Z
# 24  Building Ethical AI: A Practical Guide to Resp...  2025-06-23T20:01:59Z
#
#                Authors                                              Tags  \
# 1       David Mezzetti                     #ai #llm #rag #vectordatabase
# 2           olver team
# 5               Vaiber            #programming #declarative #sql #prolog
# 7           Mia Koring    #computerscience #algorithms #swift #beginners
# 8       Brandon Atonte
# 9           Sigurdur B                 #api #fintech #compliance #python
# 11            sempre76             #webdev #seo #typescript #programming
# 12            Codanyks                       #ai #mcp #programming #node
# 13              Edna N
# 14          Mark Gyles
# 15        Augustus otu      #webdev #programming #javascript #typescript
# 16         Ian Sosunov          #cryptography #blockchain #privacy #tlsn
# 17       Navas Herbert
# 19  Eric Augustinowicz   #multiverse #metaphor #development #datascience
# 20       Freedom Coder  #cisco #iosxewebui #cybersecurity #vulnerability
# 21       Vincent Tommi     #beginners #programming #productivity #webdev
# 22   Sospeter Mong'are     #beginners #programming #productivity #webdev
# 23  DevOps Fundamental  #bigdata #dataengineering #data #bigdatatutorial
# 24              Vaiber            #ai #machinelearning #python #tutorial
#
#     Reading_Time                                    Article_Content Language
# 1              7  txtai is an all-in-one AI framework for semant...  English
# 2              3   personaController.java  @DateTimeFormat(patte...  English
# 5              7  Welcome, fellow developers and curious minds! ...  English
# 7              1  Ever wondered how file compression actually wo...  English
# 8              4  The cybersecurity landscape is facing an unpre...  English
# 9              2  Goal: show you how to screen names against glo...  English
# 11             1  We're excited to release pyseoa-ts v0.2.0, a T...  English
# 12             5  If you’ve ever built anything slightly more co...  English
# 13             1  A visual-first layout system that treats the i...  English
# 14             2  Author: Tobie Morgan Hitchcock This blog post ...  English
# 15            17  By the Toki Space Team Building a fully-featur...  English
# 16             2  Working on Bring ID I've dived into the TLSNot...  English
# 17             4  An AI-powered content generation tool that cre...  English
# 19             3  Captain's Log, supplemental. Metaphors are a u...  English
# 20             2  CVE-2023-20198 Cisco IOS XE Web UI Privilege E...  English
# 21             1                                                     English
# 22             2  From the perspective of a senior software engi...  English
# 23             5  The relentless growth of data presents a const...  English
# 24             7  The rapid advancement and pervasive integratio...  English

# %%
#CREATE TABLE IF NOT EXISTS  article
#(
 #   Link Text Primary Key,
#	Title Text,
#	Time_Uploaded TIMESTAMP,
#	Authors Text,
#	Tags Text,
#	Reading_Time Integer,
#	Article_Content Text,
#	Word_Count Integer,
#	Sentiment Text,
#	Compound_Score Numeric,
#	Language Text
#	);

# %%
import psycopg2
db_parms = {
    "dbname": "postgres" ,
    "user": os.getenv("DB_USER") ,
    "password" :os.getenv("DB_PASSWORD"),
    "host" : os.getenv("DB_HOST"),
    "port" :"5432"
}

try:
    #connect to postgreSQL
    conn = psycopg2.connect (**db_parms)
    cursor = conn.cursor()
    
    #sql insert query
    insert_query ="""
    Insert Into articles (Link, Title, Time_Uploaded, Authors, Tags, Reading_Time, Article_Content ,Word_Count, Sentiment, Compound_Score, Language )
    Values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
    ON CONFLICT (Link) DO NOTHING
    """
    
    # insert DataFrame records one by one
    for _, row in merge_df.iterrows():
        cursor.execute(insert_query,(
            row['Link'], row['Title'],row['Time_Uploaded'] ,row['Authors'], row['Tags'], row['Reading_Time'],
            row['Article_Content'],row['Word_Count'],row['Sentiment'], row['Compound_Score'],row['Language']
        ))
        
    #commit 
    conn.commit()   
    print ("Data inserted successfully!")

except Exception as e:
    print(e)
    
finally:
    if conn:
        cursor.close () 
        conn.close
# Out:
# 'Word_Count'

# %%
print("Total rows in merge_df:", len(merge_df))
# Out:
# Total rows in merge_df: 19
