# %%
#pip install requests pandas fake_useragent bs4 langid pycountry nltk

# %%
import  requests
from bs4 import BeautifulSoup
from fake_useragent import UserAgent #used to create fake user inorder for requests
import pandas as pd
import os

url = 'https://dev.to/latest'

ua=UserAgent()
userAgent= ua.random
headers= {'User_Agent': userAgent}
page = requests.get(url, headers = headers)
soup= BeautifulSoup(page.content,'html.parser')

# %%
blog_box = soup.find_all('div' ,'crayons-story')

links = [] 
titles = [] 
time_uploaded = []  
authors = []
tags = []
reading_times = []


for box in blog_box:
    #links
    if box.find('h2', class_ = 'crayons-story__title') is not None:
        link =  box.find('h2', class_ = 'crayons-story__title').a
        link = link['href']
        links.append(link)
    else:
        links.append('None')  
        
    #titles    
    if box.find('h2', class_ = 'crayons-story__title') is not None:
        title =  box.find('h2', class_ = 'crayons-story__title')
        titles.append(title.text.replace('\n','').strip())
    else:
        titles.append('None')          

    #time_uploaded 
    if box.find('time', attrs={'datetime': True}) is not None:
        time_upload =  box.find('time', attrs={'datetime': True})
        time_upload= time_upload['datetime']
        time_uploaded.append (time_upload)
    else:
        time_uploaded.append('None') 

    #authors 
    if box.find('a', class_ = 'crayons-story__secondary fw-medium m:hidden') is not None:
        author =  box.find('a', class_ = 'crayons-story__secondary fw-medium m:hidden')
        authors.append(author.text.replace('\n','').strip())
    else:
        authors.append('None')  


    #tags  
    if box.find('div', class_ = 'crayons-story__tags') is not None:
        tag =  box.find('div', class_ = 'crayons-story__tags')
        tags.append(tag.text.replace('\n',' ').strip())
    else:
        tags.append('None')
        
 #reading_time  
    if box.find('div', class_ = 'crayons-story__save') is not None:
        reading_time  =  box.find('div', class_ = 'crayons-story__save')
        reading_times.append(reading_time.text.replace('\n',' ').strip())
    else:
        reading_times.append('None')  
  
  
df = pd.DataFrame(
    {
    'Link' : links,
    'Title' : titles,
    'Time_Uploaded' : time_uploaded ,
    'Authors' : authors,
    'Tags' : tags,
    'Reading_Time' : reading_times
    }
) 

df= df[ df['Link'] != 'None']

df
# Out:
#                                                  Link  \
# 2   https://dev.to/chaitanya_chopde_dd0642ed/build...
# 3   https://dev.to/alex_stewart_ee973ece52be/if-pr...
# 4   https://dev.to/carloseduardoalvesviana/o-que-e...
# 5   https://dev.to/dev_patel_35864ca1db6093c/the-a...
# 6   https://dev.to/saijamii/implementing-a-cdn-in-...
# 7   https://dev.to/sivarampg/cloudflare-containers...
# 8   https://dev.to/shaohushuo/harmonyos-native-dev...
# 9   https://dev.to/istealersn_dev/how-have-you-app...
# 10  https://dev.to/devopsfundamentals/gcp-fundamen...
# 11  https://dev.to/jasonliu112/why-embedded-design...
# 12  https://dev.to/lambdatest/19-best-practices-fo...
# 13  https://dev.to/seatunnel/a-deep-dive-into-seat...
# 14  https://dev.to/keneojiteli/cloud-networking-in...
# 15  https://dev.to/czmilo/impact-analysis-google-d...
# 16  https://dev.to/alsetchannel/razoes-e-proporcoe...
# 17  https://dev.to/sebastian_reid999/5-smart-ai-to...
# 18  https://dev.to/vetriselvan_11/from-attribute-t...
# 19  https://dev.to/vaib/top-15-must-have-resources...
# 20  https://dev.to/vaib/boost-performance-simplify...
# 21  https://dev.to/anil_csimplifyit_905c/the-impor...
# 22  https://dev.to/rakshitnayak/how-to-install-nvm...
# 23  https://dev.to/bugblitz98/no-more-boring-roadm...
# 24  https://dev.to/flfljh/harmonyos-flutter-wakelo...
# 25  https://dev.to/flfljh/harmonyos-flutter-video-...
# 26  https://dev.to/dev_nazwashabrina/modul-tampilk...
#
#                                                 Title         Time_Uploaded  \
# 2   🚿 Building a Simple Responsive Website for a M...  2025-06-25T03:09:34Z
# 3                If programming languages were people  2025-06-25T03:10:30Z
# 4                                      O que é REST ?  2025-06-25T03:09:51Z
# 5   The Art of Deception: Understanding Generative...  2025-06-25T03:08:29Z
# 6   Implementing a CDN in Your React App in 3 Simp...  2025-06-25T03:06:21Z
# 7   Cloudflare Containers Are Here: Deploy Docker ...  2025-06-25T03:02:03Z
# 8   HarmonyOS Native Development Notes: 03-The Who...  2025-06-25T02:59:21Z
# 9   How have you approached your strategy to setup...  2025-06-25T02:49:51Z
# 10           GCP Fundamentals: Container Analysis API  2025-06-25T02:48:30Z
# 11  Why Embedded Designers Should Care About DDR4 ...  2025-06-25T02:40:18Z
# 12  19 Best Practices for Automation Testing with ...  2025-06-25T02:38:50Z
# 13  A Deep Dive Into SeaTunnel's Thread Sharing Me...  2025-06-25T02:30:19Z
# 14  Cloud Networking in Practice: Building a Highl...  2025-06-25T02:24:10Z
# 15  Impact Analysis: Google Donating A2A Protocol ...  2025-06-25T02:22:17Z
# 16                                Razões e Proporções  2025-06-25T02:15:39Z
# 17     5 Smart AI Tools That Supercharge Productivity  2025-06-25T02:14:55Z
# 18  From @Attribute to HostAttributeToken: A Moder...  2025-06-25T02:02:44Z
# 19  Top 15+ Must-Have Resources for Exploring Mixe...  2025-06-25T02:02:24Z
# 20  Boost Performance & Simplify Microservices: Th...  2025-06-25T02:01:49Z
# 21  The Importance of Data Quality in AI-based Tes...  2025-06-25T01:59:30Z
# 22                        How to Install NVM on macOS  2025-06-25T01:41:37Z
# 23  No More Boring Roadmaps — I Built an AI That D...  2025-06-25T01:38:27Z
# 24  HarmonyOS Flutter Wakelock Plugin (Screen Wake...  2025-06-25T01:18:12Z
# 25  HarmonyOS Flutter Video Trimmer (Video Clippin...  2025-06-25T01:17:45Z
# 26  Modul tampilkan di Earl: Menampilkan Nilai den...  2025-06-25T01:17:24Z
#
#                       Authors  \
# 2            Chaitanya Chopde
# 3                Alex Stewart
# 4                Carlos Viana
# 5                   Dev Patel
# 6                     saijami
# 7                     Sivaram
# 8                  shaohushuo
# 9                   Stanley J
# 10         DevOps Fundamental
# 11                jasonliu112
# 12              Harish Rajora
# 13           Apache SeaTunnel
# 14               Kene Ojiteli
# 15                         cz
# 16              Alset Channel
# 17             Sebastian Reid
# 18  vetriselvan Panneerselvam
# 19                     Vaiber
# 20                     Vaiber
# 21                   Anil Pal
# 22              Rakshit Nayak
# 23                  Bug Blitz
# 24                     flfljh
# 25                     flfljh
# 26        Nazwa Shabrina Zain
#
#                                                  Tags Reading_Time
# 2                   #motorpump #html #css #javascript   2 min read
# 3                                                       1 min read
# 4                                                       2 min read
# 5           #machinelearning #python #datascience #ai   3 min read
# 6                    #cdn #react #webdev #performance   2 min read
# 7                     #cloudflare #webdev #devops #ai   3 min read
# 8                                 #harmonyos #harmony   4 min read
# 9               #api #programming #webdev #javascript   1 min read
# 10    #gcp #googlecloud #devops #containeranalysisapi   8 min read
# 11                                        #emmc #ddr4   1 min read
# 12  #automationtesting #node #softwaretesting #lam...  14 min read
# 13                                                      4 min read
# 14                   #aws #vpc #terraform #networking   9 min read
# 15                                               #a2a   3 min read
# 16                                                      2 min read
# 17                  #tech #ai #automation #technology  14 min read
# 18   #angular #javascript #typescript #injectiontoken   3 min read
# 19  #mixedreality #xr #spatialcomputing #augmented...   5 min read
# 20         #microservices #api #architecture #backend   7 min read
# 21                                                      3 min read
# 22                            #programming #nvm #node   1 min read
# 23               #webdev #javascript #programming #ai   1 min read
# 24                                                      3 min read
# 25                                                      2 min read
# 26     #programming #opensource #beginners #indonesia   2 min read

# %%
##Second_url = 'https://dev.to/sejdi_gashi/live-and-online-our-food-waste-reduction-platform-is-almost-ready-5dfi'
article = []
article_link = []

def get_full_content (Second_url):
    ua=UserAgent()
    userAgent= ua.random
    headers= {'User_Agent': userAgent}
    page = requests.get(Second_url, headers = headers)
    soup= BeautifulSoup(page.content,'html.parser')
    print(Second_url)

    content = soup.find ('div',class_='crayons-article__main')
    paragrphs = content.find_all('p')

    contents = []
    for i in paragrphs:
        contents.append(i.text.replace('\n',' '))
    
    string  = ' '.join(contents)
    article.append (string)
    article_link.append(Second_url)

for i in df.Link:
    get_full_content(i)
article_df = pd.DataFrame(
      {
      'Article_Content' : article,
      'Link' : article_link
      }
    )

article_df
# Out:
# https://dev.to/chaitanya_chopde_dd0642ed/building-a-simple-responsive-website-for-a-motor-pump-company-using-html-css-javascript-502p
# https://dev.to/alex_stewart_ee973ece52be/if-programming-languages-were-people-594e
# https://dev.to/carloseduardoalvesviana/o-que-e-rest--3blk
# https://dev.to/dev_patel_35864ca1db6093c/the-art-of-deception-understanding-generative-adversarial-networks-gans-3j5d
# https://dev.to/saijamii/implementing-a-cdn-in-your-react-app-in-3-simple-steps-5fdc
# https://dev.to/sivarampg/cloudflare-containers-are-here-deploy-docker-globally-with-a-single-command-4e1m
# https://dev.to/shaohushuo/harmonyos-native-development-notes-03-the-whole-process-of-meta-service-development-3nee
# https://dev.to/istealersn_dev/how-have-you-approached-your-strategy-to-setup-headless-cms-3n24
# https://dev.to/devopsfundamentals/gcp-fundamentals-container-analysis-api-95d
# https://dev.to/jasonliu112/why-embedded-designers-should-care-about-ddr4-emmc-stockpiling-25k9
# https://dev.to/lambdatest/19-best-practices-for-automation-testing-with-nodejs-47e7
# https://dev.to/seatunnel/a-deep-dive-into-seatunnels-thread-sharing-mechanism-and-task-execution-model-optimization-1ejk
# https://dev.to/keneojiteli/cloud-networking-in-practice-building-a-highly-available-vpc-on-aws-with-terraform-2ae8
# https://dev.to/czmilo/impact-analysis-google-donating-a2a-protocol-to-linux-foundation-3efc
# https://dev.to/alsetchannel/razoes-e-proporcoes-1go2
# https://dev.to/sebastian_reid999/5-smart-ai-tools-that-supercharge-productivity-33gb
# https://dev.to/vetriselvan_11/from-attribute-to-hostattributetoken-a-modern-angular-di-pattern-47jf
# https://dev.to/vaib/top-15-must-have-resources-for-exploring-mixed-reality-mr-development-22i4
# https://dev.to/vaib/boost-performance-simplify-microservices-the-api-gateway-aggregation-pattern-52hi
# https://dev.to/anil_csimplifyit_905c/the-importance-of-data-quality-in-ai-based-testing-2lo3
# https://dev.to/rakshitnayak/how-to-install-nvm-on-macos-gbf
# https://dev.to/bugblitz98/no-more-boring-roadmaps-i-built-an-ai-that-designs-yours-visually-286p
# https://dev.to/flfljh/harmonyos-flutter-wakelock-plugin-screen-wake-lock-management-b20
# https://dev.to/flfljh/harmonyos-flutter-video-trimmer-video-clipping-implementation-3dkd
# https://dev.to/dev_nazwashabrina/modul-tampilkan-di-earl-menampilkan-nilai-dengan-format-yang-terkontrol-1ln8
#                                       Article_Content  \
# 0   This blog is part of my @devsyncin  learning j...
# 1      As you can tell by this video, we've been h...
# 2   REST (Representational State Transfer) é um es...
# 3   Imagine two artists locked in a fierce competi...
# 4   Leverage a CDN to slash load times and offload...
# 5   Forget managing regions, orchestrators, or art...
# 6   This article provides a very detailed introduc...
# 7
# 8   The modern software landscape is characterized...
# 9   As DDR4 and eMMC prices skyrocket due to produ...
# 10  Node.js has become one of the most popular fra...
# 11  The Apache SeaTunnel Zeta engine is a dedicate...
# 12  After grasping the concepts of Networking, Sub...
# 13  Google's donation of the Agent2Agent (A2A) pro...
# 14  Razão é uma comparação entre dois valores, fei...
# 15  What would you do with an extra 21.8 hours a w...
# 16  Hey devs! 👋 As promised, we're continuing our ...
# 17  Welcome, fellow explorers of the digital front...
# 18  The Power of API Gateway Aggregation: Simplify...
# 19   In the era of AI-driven software development,...
# 20  If you're a developer working with Node.js, ma...
# 21  Are you tired of static roadmap templates that...
# 22  Defining the Wakelock API  Integrating with Fl...
# 23  videotrimmer is a third-party library for vide...
# 24  Teks ini beberapa dibuat oleh generative AI Si...
#
#                                                  Link
# 0   https://dev.to/chaitanya_chopde_dd0642ed/build...
# 1   https://dev.to/alex_stewart_ee973ece52be/if-pr...
# 2   https://dev.to/carloseduardoalvesviana/o-que-e...
# 3   https://dev.to/dev_patel_35864ca1db6093c/the-a...
# 4   https://dev.to/saijamii/implementing-a-cdn-in-...
# 5   https://dev.to/sivarampg/cloudflare-containers...
# 6   https://dev.to/shaohushuo/harmonyos-native-dev...
# 7   https://dev.to/istealersn_dev/how-have-you-app...
# 8   https://dev.to/devopsfundamentals/gcp-fundamen...
# 9   https://dev.to/jasonliu112/why-embedded-design...
# 10  https://dev.to/lambdatest/19-best-practices-fo...
# 11  https://dev.to/seatunnel/a-deep-dive-into-seat...
# 12  https://dev.to/keneojiteli/cloud-networking-in...
# 13  https://dev.to/czmilo/impact-analysis-google-d...
# 14  https://dev.to/alsetchannel/razoes-e-proporcoe...
# 15  https://dev.to/sebastian_reid999/5-smart-ai-to...
# 16  https://dev.to/vetriselvan_11/from-attribute-t...
# 17  https://dev.to/vaib/top-15-must-have-resources...
# 18  https://dev.to/vaib/boost-performance-simplify...
# 19  https://dev.to/anil_csimplifyit_905c/the-impor...
# 20  https://dev.to/rakshitnayak/how-to-install-nvm...
# 21  https://dev.to/bugblitz98/no-more-boring-roadm...
# 22  https://dev.to/flfljh/harmonyos-flutter-wakelo...
# 23  https://dev.to/flfljh/harmonyos-flutter-video-...
# 24  https://dev.to/dev_nazwashabrina/modul-tampilk...

# %%
#merge 2 dataframe
merge_df = pd.merge(df, article_df, on = 'Link', how='inner')
merge_df
# Out:
#                                                  Link  \
# 0   https://dev.to/chaitanya_chopde_dd0642ed/build...
# 1   https://dev.to/alex_stewart_ee973ece52be/if-pr...
# 2   https://dev.to/carloseduardoalvesviana/o-que-e...
# 3   https://dev.to/dev_patel_35864ca1db6093c/the-a...
# 4   https://dev.to/saijamii/implementing-a-cdn-in-...
# 5   https://dev.to/sivarampg/cloudflare-containers...
# 6   https://dev.to/shaohushuo/harmonyos-native-dev...
# 7   https://dev.to/istealersn_dev/how-have-you-app...
# 8   https://dev.to/devopsfundamentals/gcp-fundamen...
# 9   https://dev.to/jasonliu112/why-embedded-design...
# 10  https://dev.to/lambdatest/19-best-practices-fo...
# 11  https://dev.to/seatunnel/a-deep-dive-into-seat...
# 12  https://dev.to/keneojiteli/cloud-networking-in...
# 13  https://dev.to/czmilo/impact-analysis-google-d...
# 14  https://dev.to/alsetchannel/razoes-e-proporcoe...
# 15  https://dev.to/sebastian_reid999/5-smart-ai-to...
# 16  https://dev.to/vetriselvan_11/from-attribute-t...
# 17  https://dev.to/vaib/top-15-must-have-resources...
# 18  https://dev.to/vaib/boost-performance-simplify...
# 19  https://dev.to/anil_csimplifyit_905c/the-impor...
# 20  https://dev.to/rakshitnayak/how-to-install-nvm...
# 21  https://dev.to/bugblitz98/no-more-boring-roadm...
# 22  https://dev.to/flfljh/harmonyos-flutter-wakelo...
# 23  https://dev.to/flfljh/harmonyos-flutter-video-...
# 24  https://dev.to/dev_nazwashabrina/modul-tampilk...
#
#                                                 Title         Time_Uploaded  \
# 0   🚿 Building a Simple Responsive Website for a M...  2025-06-25T03:09:34Z
# 1                If programming languages were people  2025-06-25T03:10:30Z
# 2                                      O que é REST ?  2025-06-25T03:09:51Z
# 3   The Art of Deception: Understanding Generative...  2025-06-25T03:08:29Z
# 4   Implementing a CDN in Your React App in 3 Simp...  2025-06-25T03:06:21Z
# 5   Cloudflare Containers Are Here: Deploy Docker ...  2025-06-25T03:02:03Z
# 6   HarmonyOS Native Development Notes: 03-The Who...  2025-06-25T02:59:21Z
# 7   How have you approached your strategy to setup...  2025-06-25T02:49:51Z
# 8            GCP Fundamentals: Container Analysis API  2025-06-25T02:48:30Z
# 9   Why Embedded Designers Should Care About DDR4 ...  2025-06-25T02:40:18Z
# 10  19 Best Practices for Automation Testing with ...  2025-06-25T02:38:50Z
# 11  A Deep Dive Into SeaTunnel's Thread Sharing Me...  2025-06-25T02:30:19Z
# 12  Cloud Networking in Practice: Building a Highl...  2025-06-25T02:24:10Z
# 13  Impact Analysis: Google Donating A2A Protocol ...  2025-06-25T02:22:17Z
# 14                                Razões e Proporções  2025-06-25T02:15:39Z
# 15     5 Smart AI Tools That Supercharge Productivity  2025-06-25T02:14:55Z
# 16  From @Attribute to HostAttributeToken: A Moder...  2025-06-25T02:02:44Z
# 17  Top 15+ Must-Have Resources for Exploring Mixe...  2025-06-25T02:02:24Z
# 18  Boost Performance & Simplify Microservices: Th...  2025-06-25T02:01:49Z
# 19  The Importance of Data Quality in AI-based Tes...  2025-06-25T01:59:30Z
# 20                        How to Install NVM on macOS  2025-06-25T01:41:37Z
# 21  No More Boring Roadmaps — I Built an AI That D...  2025-06-25T01:38:27Z
# 22  HarmonyOS Flutter Wakelock Plugin (Screen Wake...  2025-06-25T01:18:12Z
# 23  HarmonyOS Flutter Video Trimmer (Video Clippin...  2025-06-25T01:17:45Z
# 24  Modul tampilkan di Earl: Menampilkan Nilai den...  2025-06-25T01:17:24Z
#
#                       Authors  \
# 0            Chaitanya Chopde
# 1                Alex Stewart
# 2                Carlos Viana
# 3                   Dev Patel
# 4                     saijami
# 5                     Sivaram
# 6                  shaohushuo
# 7                   Stanley J
# 8          DevOps Fundamental
# 9                 jasonliu112
# 10              Harish Rajora
# 11           Apache SeaTunnel
# 12               Kene Ojiteli
# 13                         cz
# 14              Alset Channel
# 15             Sebastian Reid
# 16  vetriselvan Panneerselvam
# 17                     Vaiber
# 18                     Vaiber
# 19                   Anil Pal
# 20              Rakshit Nayak
# 21                  Bug Blitz
# 22                     flfljh
# 23                     flfljh
# 24        Nazwa Shabrina Zain
#
#                                                  Tags Reading_Time  \
# 0                   #motorpump #html #css #javascript   2 min read
# 1                                                       1 min read
# 2                                                       2 min read
# 3           #machinelearning #python #datascience #ai   3 min read
# 4                    #cdn #react #webdev #performance   2 min read
# 5                     #cloudflare #webdev #devops #ai   3 min read
# 6                                 #harmonyos #harmony   4 min read
# 7               #api #programming #webdev #javascript   1 min read
# 8     #gcp #googlecloud #devops #containeranalysisapi   8 min read
# 9                                         #emmc #ddr4   1 min read
# 10  #automationtesting #node #softwaretesting #lam...  14 min read
# 11                                                      4 min read
# 12                   #aws #vpc #terraform #networking   9 min read
# 13                                               #a2a   3 min read
# 14                                                      2 min read
# 15                  #tech #ai #automation #technology  14 min read
# 16   #angular #javascript #typescript #injectiontoken   3 min read
# 17  #mixedreality #xr #spatialcomputing #augmented...   5 min read
# 18         #microservices #api #architecture #backend   7 min read
# 19                                                      3 min read
# 20                            #programming #nvm #node   1 min read
# 21               #webdev #javascript #programming #ai   1 min read
# 22                                                      3 min read
# 23                                                      2 min read
# 24     #programming #opensource #beginners #indonesia   2 min read
#
#                                       Article_Content
# 0   This blog is part of my @devsyncin  learning j...
# 1      As you can tell by this video, we've been h...
# 2   REST (Representational State Transfer) é um es...
# 3   Imagine two artists locked in a fierce competi...
# 4   Leverage a CDN to slash load times and offload...
# 5   Forget managing regions, orchestrators, or art...
# 6   This article provides a very detailed introduc...
# 7
# 8   The modern software landscape is characterized...
# 9   As DDR4 and eMMC prices skyrocket due to produ...
# 10  Node.js has become one of the most popular fra...
# 11  The Apache SeaTunnel Zeta engine is a dedicate...
# 12  After grasping the concepts of Networking, Sub...
# 13  Google's donation of the Agent2Agent (A2A) pro...
# 14  Razão é uma comparação entre dois valores, fei...
# 15  What would you do with an extra 21.8 hours a w...
# 16  Hey devs! 👋 As promised, we're continuing our ...
# 17  Welcome, fellow explorers of the digital front...
# 18  The Power of API Gateway Aggregation: Simplify...
# 19   In the era of AI-driven software development,...
# 20  If you're a developer working with Node.js, ma...
# 21  Are you tired of static roadmap templates that...
# 22  Defining the Wakelock API  Integrating with Fl...
# 23  videotrimmer is a third-party library for vide...
# 24  Teks ini beberapa dibuat oleh generative AI Si...

# %%
from nltk.corpus import stopwords
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

#Download the stopword datasets
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('vader_lexicon')
#nltk.download('punket_tab')

def count_words_without_stopwords(text):
    if isinstance(text,(str,bytes)):
        words = nltk.word_tokenize(str(text))
        stop_words = set(stopwords.words('english'))
        filtered_words = [word for word in words if word.lower() not in stop_words ]
        return  len(filtered_words)  
    else:
        0
        
merge_df ['Word_Count']  = merge_df ['Article_Content'].apply(count_words_without_stopwords)  
merge_df
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\feven/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to C:\Users\feven/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\feven/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\feven/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
#                                                  Link  \
# 0   https://dev.to/chaitanya_chopde_dd0642ed/build...
# 1   https://dev.to/alex_stewart_ee973ece52be/if-pr...
# 2   https://dev.to/carloseduardoalvesviana/o-que-e...
# 3   https://dev.to/dev_patel_35864ca1db6093c/the-a...
# 4   https://dev.to/saijamii/implementing-a-cdn-in-...
# 5   https://dev.to/sivarampg/cloudflare-containers...
# 6   https://dev.to/shaohushuo/harmonyos-native-dev...
# 7   https://dev.to/istealersn_dev/how-have-you-app...
# 8   https://dev.to/devopsfundamentals/gcp-fundamen...
# 9   https://dev.to/jasonliu112/why-embedded-design...
# 10  https://dev.to/lambdatest/19-best-practices-fo...
# 11  https://dev.to/seatunnel/a-deep-dive-into-seat...
# 12  https://dev.to/keneojiteli/cloud-networking-in...
# 13  https://dev.to/czmilo/impact-analysis-google-d...
# 14  https://dev.to/alsetchannel/razoes-e-proporcoe...
# 15  https://dev.to/sebastian_reid999/5-smart-ai-to...
# 16  https://dev.to/vetriselvan_11/from-attribute-t...
# 17  https://dev.to/vaib/top-15-must-have-resources...
# 18  https://dev.to/vaib/boost-performance-simplify...
# 19  https://dev.to/anil_csimplifyit_905c/the-impor...
# 20  https://dev.to/rakshitnayak/how-to-install-nvm...
# 21  https://dev.to/bugblitz98/no-more-boring-roadm...
# 22  https://dev.to/flfljh/harmonyos-flutter-wakelo...
# 23  https://dev.to/flfljh/harmonyos-flutter-video-...
# 24  https://dev.to/dev_nazwashabrina/modul-tampilk...
#
#                                                 Title         Time_Uploaded  \
# 0   🚿 Building a Simple Responsive Website for a M...  2025-06-25T03:09:34Z
# 1                If programming languages were people  2025-06-25T03:10:30Z
# 2                                      O que é REST ?  2025-06-25T03:09:51Z
# 3   The Art of Deception: Understanding Generative...  2025-06-25T03:08:29Z
# 4   Implementing a CDN in Your React App in 3 Simp...  2025-06-25T03:06:21Z
# 5   Cloudflare Containers Are Here: Deploy Docker ...  2025-06-25T03:02:03Z
# 6   HarmonyOS Native Development Notes: 03-The Who...  2025-06-25T02:59:21Z
# 7   How have you approached your strategy to setup...  2025-06-25T02:49:51Z
# 8            GCP Fundamentals: Container Analysis API  2025-06-25T02:48:30Z
# 9   Why Embedded Designers Should Care About DDR4 ...  2025-06-25T02:40:18Z
# 10  19 Best Practices for Automation Testing with ...  2025-06-25T02:38:50Z
# 11  A Deep Dive Into SeaTunnel's Thread Sharing Me...  2025-06-25T02:30:19Z
# 12  Cloud Networking in Practice: Building a Highl...  2025-06-25T02:24:10Z
# 13  Impact Analysis: Google Donating A2A Protocol ...  2025-06-25T02:22:17Z
# 14                                Razões e Proporções  2025-06-25T02:15:39Z
# 15     5 Smart AI Tools That Supercharge Productivity  2025-06-25T02:14:55Z
# 16  From @Attribute to HostAttributeToken: A Moder...  2025-06-25T02:02:44Z
# 17  Top 15+ Must-Have Resources for Exploring Mixe...  2025-06-25T02:02:24Z
# 18  Boost Performance & Simplify Microservices: Th...  2025-06-25T02:01:49Z
# 19  The Importance of Data Quality in AI-based Tes...  2025-06-25T01:59:30Z
# 20                        How to Install NVM on macOS  2025-06-25T01:41:37Z
# 21  No More Boring Roadmaps — I Built an AI That D...  2025-06-25T01:38:27Z
# 22  HarmonyOS Flutter Wakelock Plugin (Screen Wake...  2025-06-25T01:18:12Z
# 23  HarmonyOS Flutter Video Trimmer (Video Clippin...  2025-06-25T01:17:45Z
# 24  Modul tampilkan di Earl: Menampilkan Nilai den...  2025-06-25T01:17:24Z
#
#                       Authors  \
# 0            Chaitanya Chopde
# 1                Alex Stewart
# 2                Carlos Viana
# 3                   Dev Patel
# 4                     saijami
# 5                     Sivaram
# 6                  shaohushuo
# 7                   Stanley J
# 8          DevOps Fundamental
# 9                 jasonliu112
# 10              Harish Rajora
# 11           Apache SeaTunnel
# 12               Kene Ojiteli
# 13                         cz
# 14              Alset Channel
# 15             Sebastian Reid
# 16  vetriselvan Panneerselvam
# 17                     Vaiber
# 18                     Vaiber
# 19                   Anil Pal
# 20              Rakshit Nayak
# 21                  Bug Blitz
# 22                     flfljh
# 23                     flfljh
# 24        Nazwa Shabrina Zain
#
#                                                  Tags Reading_Time  \
# 0                   #motorpump #html #css #javascript   2 min read
# 1                                                       1 min read
# 2                                                       2 min read
# 3           #machinelearning #python #datascience #ai   3 min read
# 4                    #cdn #react #webdev #performance   2 min read
# 5                     #cloudflare #webdev #devops #ai   3 min read
# 6                                 #harmonyos #harmony   4 min read
# 7               #api #programming #webdev #javascript   1 min read
# 8     #gcp #googlecloud #devops #containeranalysisapi   8 min read
# 9                                         #emmc #ddr4   1 min read
# 10  #automationtesting #node #softwaretesting #lam...  14 min read
# 11                                                      4 min read
# 12                   #aws #vpc #terraform #networking   9 min read
# 13                                               #a2a   3 min read
# 14                                                      2 min read
# 15                  #tech #ai #automation #technology  14 min read
# 16   #angular #javascript #typescript #injectiontoken   3 min read
# 17  #mixedreality #xr #spatialcomputing #augmented...   5 min read
# 18         #microservices #api #architecture #backend   7 min read
# 19                                                      3 min read
# 20                            #programming #nvm #node   1 min read
# 21               #webdev #javascript #programming #ai   1 min read
# 22                                                      3 min read
# 23                                                      2 min read
# 24     #programming #opensource #beginners #indonesia   2 min read
#
#                                       Article_Content  Word_Count
# 0   This blog is part of my @devsyncin  learning j...         304
# 1      As you can tell by this video, we've been h...          84
# 2   REST (Representational State Transfer) é um es...          52
# 3   Imagine two artists locked in a fierce competi...         445
# 4   Leverage a CDN to slash load times and offload...         165
# 5   Forget managing regions, orchestrators, or art...         217
# 6   This article provides a very detailed introduc...         466
# 7                                                               0
# 8   The modern software landscape is characterized...         450
# 9   As DDR4 and eMMC prices skyrocket due to produ...          91
# 10  Node.js has become one of the most popular fra...        1923
# 11  The Apache SeaTunnel Zeta engine is a dedicate...         497
# 12  After grasping the concepts of Networking, Sub...         337
# 13  Google's donation of the Agent2Agent (A2A) pro...         251
# 14  Razão é uma comparação entre dois valores, fei...         141
# 15  What would you do with an extra 21.8 hours a w...        2454
# 16  Hey devs! 👋 As promised, we're continuing our ...         169
# 17  Welcome, fellow explorers of the digital front...         366
# 18  The Power of API Gateway Aggregation: Simplify...         534
# 19   In the era of AI-driven software development,...         661
# 20  If you're a developer working with Node.js, ma...         130
# 21  Are you tired of static roadmap templates that...         180
# 22  Defining the Wakelock API  Integrating with Fl...           9
# 23  videotrimmer is a third-party library for vide...          34
# 24  Teks ini beberapa dibuat oleh generative AI Si...         372

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import pandas as pd
sid = SentimentIntensityAnalyzer()

def get_sentiment(row):
    
    sentiment_scores = sid.polarity_scores(merge_df.Article_Content[20])
    compound_score = sentiment_scores['compound']

    if compound_score >= 0.05:
      sentiment = 'Positive'
    elif compound_score <=  -0.05:
      sentiment = 'Negative'
    else:
      sentiment = 'Neutral' 
     
    return sentiment , compound_score   
         
#df[['Sentiment' , 'Compound_Score']] = df['Article_Content'].astype(str).apply(lambda x: pd.Series(get_sentiment(x)))
merge_df[['Sentiment', 'Compound_Score']] = merge_df['Article_Content'].astype(str).apply( lambda x: pd.Series(get_sentiment(x)))   
merge_df
# Out:
#                                                  Link  \
# 0   https://dev.to/chaitanya_chopde_dd0642ed/build...
# 1   https://dev.to/alex_stewart_ee973ece52be/if-pr...
# 2   https://dev.to/carloseduardoalvesviana/o-que-e...
# 3   https://dev.to/dev_patel_35864ca1db6093c/the-a...
# 4   https://dev.to/saijamii/implementing-a-cdn-in-...
# 5   https://dev.to/sivarampg/cloudflare-containers...
# 6   https://dev.to/shaohushuo/harmonyos-native-dev...
# 7   https://dev.to/istealersn_dev/how-have-you-app...
# 8   https://dev.to/devopsfundamentals/gcp-fundamen...
# 9   https://dev.to/jasonliu112/why-embedded-design...
# 10  https://dev.to/lambdatest/19-best-practices-fo...
# 11  https://dev.to/seatunnel/a-deep-dive-into-seat...
# 12  https://dev.to/keneojiteli/cloud-networking-in...
# 13  https://dev.to/czmilo/impact-analysis-google-d...
# 14  https://dev.to/alsetchannel/razoes-e-proporcoe...
# 15  https://dev.to/sebastian_reid999/5-smart-ai-to...
# 16  https://dev.to/vetriselvan_11/from-attribute-t...
# 17  https://dev.to/vaib/top-15-must-have-resources...
# 18  https://dev.to/vaib/boost-performance-simplify...
# 19  https://dev.to/anil_csimplifyit_905c/the-impor...
# 20  https://dev.to/rakshitnayak/how-to-install-nvm...
# 21  https://dev.to/bugblitz98/no-more-boring-roadm...
# 22  https://dev.to/flfljh/harmonyos-flutter-wakelo...
# 23  https://dev.to/flfljh/harmonyos-flutter-video-...
# 24  https://dev.to/dev_nazwashabrina/modul-tampilk...
#
#                                                 Title         Time_Uploaded  \
# 0   🚿 Building a Simple Responsive Website for a M...  2025-06-25T03:09:34Z
# 1                If programming languages were people  2025-06-25T03:10:30Z
# 2                                      O que é REST ?  2025-06-25T03:09:51Z
# 3   The Art of Deception: Understanding Generative...  2025-06-25T03:08:29Z
# 4   Implementing a CDN in Your React App in 3 Simp...  2025-06-25T03:06:21Z
# 5   Cloudflare Containers Are Here: Deploy Docker ...  2025-06-25T03:02:03Z
# 6   HarmonyOS Native Development Notes: 03-The Who...  2025-06-25T02:59:21Z
# 7   How have you approached your strategy to setup...  2025-06-25T02:49:51Z
# 8            GCP Fundamentals: Container Analysis API  2025-06-25T02:48:30Z
# 9   Why Embedded Designers Should Care About DDR4 ...  2025-06-25T02:40:18Z
# 10  19 Best Practices for Automation Testing with ...  2025-06-25T02:38:50Z
# 11  A Deep Dive Into SeaTunnel's Thread Sharing Me...  2025-06-25T02:30:19Z
# 12  Cloud Networking in Practice: Building a Highl...  2025-06-25T02:24:10Z
# 13  Impact Analysis: Google Donating A2A Protocol ...  2025-06-25T02:22:17Z
# 14                                Razões e Proporções  2025-06-25T02:15:39Z
# 15     5 Smart AI Tools That Supercharge Productivity  2025-06-25T02:14:55Z
# 16  From @Attribute to HostAttributeToken: A Moder...  2025-06-25T02:02:44Z
# 17  Top 15+ Must-Have Resources for Exploring Mixe...  2025-06-25T02:02:24Z
# 18  Boost Performance & Simplify Microservices: Th...  2025-06-25T02:01:49Z
# 19  The Importance of Data Quality in AI-based Tes...  2025-06-25T01:59:30Z
# 20                        How to Install NVM on macOS  2025-06-25T01:41:37Z
# 21  No More Boring Roadmaps — I Built an AI That D...  2025-06-25T01:38:27Z
# 22  HarmonyOS Flutter Wakelock Plugin (Screen Wake...  2025-06-25T01:18:12Z
# 23  HarmonyOS Flutter Video Trimmer (Video Clippin...  2025-06-25T01:17:45Z
# 24  Modul tampilkan di Earl: Menampilkan Nilai den...  2025-06-25T01:17:24Z
#
#                       Authors  \
# 0            Chaitanya Chopde
# 1                Alex Stewart
# 2                Carlos Viana
# 3                   Dev Patel
# 4                     saijami
# 5                     Sivaram
# 6                  shaohushuo
# 7                   Stanley J
# 8          DevOps Fundamental
# 9                 jasonliu112
# 10              Harish Rajora
# 11           Apache SeaTunnel
# 12               Kene Ojiteli
# 13                         cz
# 14              Alset Channel
# 15             Sebastian Reid
# 16  vetriselvan Panneerselvam
# 17                     Vaiber
# 18                     Vaiber
# 19                   Anil Pal
# 20              Rakshit Nayak
# 21                  Bug Blitz
# 22                     flfljh
# 23                     flfljh
# 24        Nazwa Shabrina Zain
#
#                                                  Tags Reading_Time  \
# 0                   #motorpump #html #css #javascript   2 min read
# 1                                                       1 min read
# 2                                                       2 min read
# 3           #machinelearning #python #datascience #ai   3 min read
# 4                    #cdn #react #webdev #performance   2 min read
# 5                     #cloudflare #webdev #devops #ai   3 min read
# 6                                 #harmonyos #harmony   4 min read
# 7               #api #programming #webdev #javascript   1 min read
# 8     #gcp #googlecloud #devops #containeranalysisapi   8 min read
# 9                                         #emmc #ddr4   1 min read
# 10  #automationtesting #node #softwaretesting #lam...  14 min read
# 11                                                      4 min read
# 12                   #aws #vpc #terraform #networking   9 min read
# 13                                               #a2a   3 min read
# 14                                                      2 min read
# 15                  #tech #ai #automation #technology  14 min read
# 16   #angular #javascript #typescript #injectiontoken   3 min read
# 17  #mixedreality #xr #spatialcomputing #augmented...   5 min read
# 18         #microservices #api #architecture #backend   7 min read
# 19                                                      3 min read
# 20                            #programming #nvm #node   1 min read
# 21               #webdev #javascript #programming #ai   1 min read
# 22                                                      3 min read
# 23                                                      2 min read
# 24     #programming #opensource #beginners #indonesia   2 min read
#
#                                       Article_Content  Word_Count Sentiment  \
# 0   This blog is part of my @devsyncin  learning j...         304  Positive
# 1      As you can tell by this video, we've been h...          84  Positive
# 2   REST (Representational State Transfer) é um es...          52  Positive
# 3   Imagine two artists locked in a fierce competi...         445  Positive
# 4   Leverage a CDN to slash load times and offload...         165  Positive
# 5   Forget managing regions, orchestrators, or art...         217  Positive
# 6   This article provides a very detailed introduc...         466  Positive
# 7                                                               0  Positive
# 8   The modern software landscape is characterized...         450  Positive
# 9   As DDR4 and eMMC prices skyrocket due to produ...          91  Positive
# 10  Node.js has become one of the most popular fra...        1923  Positive
# 11  The Apache SeaTunnel Zeta engine is a dedicate...         497  Positive
# 12  After grasping the concepts of Networking, Sub...         337  Positive
# 13  Google's donation of the Agent2Agent (A2A) pro...         251  Positive
# 14  Razão é uma comparação entre dois valores, fei...         141  Positive
# 15  What would you do with an extra 21.8 hours a w...        2454  Positive
# 16  Hey devs! 👋 As promised, we're continuing our ...         169  Positive
# 17  Welcome, fellow explorers of the digital front...         366  Positive
# 18  The Power of API Gateway Aggregation: Simplify...         534  Positive
# 19   In the era of AI-driven software development,...         661  Positive
# 20  If you're a developer working with Node.js, ma...         130  Positive
# 21  Are you tired of static roadmap templates that...         180  Positive
# 22  Defining the Wakelock API  Integrating with Fl...           9  Positive
# 23  videotrimmer is a third-party library for vide...          34  Positive
# 24  Teks ini beberapa dibuat oleh generative AI Si...         372  Positive
#
#     Compound_Score
# 0            0.296
# 1            0.296
# 2            0.296
# 3            0.296
# 4            0.296
# 5            0.296
# 6            0.296
# 7            0.296
# 8            0.296
# 9            0.296
# 10           0.296
# 11           0.296
# 12           0.296
# 13           0.296
# 14           0.296
# 15           0.296
# 16           0.296
# 17           0.296
# 18           0.296
# 19           0.296
# 20           0.296
# 21           0.296
# 22           0.296
# 23           0.296
# 24           0.296

# %%
import pandas as pd 
import langid
import pycountry

def detect_language(text) :
    # conver NAN to an empty string
    text = str(text) if pd.notna(text) else ''
    
    # use langid to detect the language
    lang, confidence = langid.classify(text)
    return lang
merge_df['Language'] =merge_df['Article_Content'].apply(detect_language)
merge_df['Language']=merge_df['Language'].map(lambda code: pycountry.languages.get(alpha_2=code).name if pycountry.languages.get(alpha_2=code) else code)

merge_df = merge_df[merge_df['Language'] == 'English']
merge_df['Reading_Time'] = merge_df['Reading_Time'].astype(str).str.replace(' min read', '', regex=False).str.strip().replace('', '0').astype(int)

    
merge_df
# Out:
# C:\Users\feven\AppData\Local\Temp\ipykernel_5072\227734844.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merge_df['Reading_Time'] = merge_df['Reading_Time'].astype(str).str.replace(' min read', '', regex=False).str.strip().replace('', '0').astype(int)
#                                                  Link  \
# 0   https://dev.to/chaitanya_chopde_dd0642ed/build...
# 1   https://dev.to/alex_stewart_ee973ece52be/if-pr...
# 3   https://dev.to/dev_patel_35864ca1db6093c/the-a...
# 4   https://dev.to/saijamii/implementing-a-cdn-in-...
# 5   https://dev.to/sivarampg/cloudflare-containers...
# 6   https://dev.to/shaohushuo/harmonyos-native-dev...
# 7   https://dev.to/istealersn_dev/how-have-you-app...
# 8   https://dev.to/devopsfundamentals/gcp-fundamen...
# 9   https://dev.to/jasonliu112/why-embedded-design...
# 10  https://dev.to/lambdatest/19-best-practices-fo...
# 11  https://dev.to/seatunnel/a-deep-dive-into-seat...
# 12  https://dev.to/keneojiteli/cloud-networking-in...
# 13  https://dev.to/czmilo/impact-analysis-google-d...
# 15  https://dev.to/sebastian_reid999/5-smart-ai-to...
# 16  https://dev.to/vetriselvan_11/from-attribute-t...
# 17  https://dev.to/vaib/top-15-must-have-resources...
# 18  https://dev.to/vaib/boost-performance-simplify...
# 19  https://dev.to/anil_csimplifyit_905c/the-impor...
# 20  https://dev.to/rakshitnayak/how-to-install-nvm...
# 21  https://dev.to/bugblitz98/no-more-boring-roadm...
# 22  https://dev.to/flfljh/harmonyos-flutter-wakelo...
# 23  https://dev.to/flfljh/harmonyos-flutter-video-...
#
#                                                 Title         Time_Uploaded  \
# 0   🚿 Building a Simple Responsive Website for a M...  2025-06-25T03:09:34Z
# 1                If programming languages were people  2025-06-25T03:10:30Z
# 3   The Art of Deception: Understanding Generative...  2025-06-25T03:08:29Z
# 4   Implementing a CDN in Your React App in 3 Simp...  2025-06-25T03:06:21Z
# 5   Cloudflare Containers Are Here: Deploy Docker ...  2025-06-25T03:02:03Z
# 6   HarmonyOS Native Development Notes: 03-The Who...  2025-06-25T02:59:21Z
# 7   How have you approached your strategy to setup...  2025-06-25T02:49:51Z
# 8            GCP Fundamentals: Container Analysis API  2025-06-25T02:48:30Z
# 9   Why Embedded Designers Should Care About DDR4 ...  2025-06-25T02:40:18Z
# 10  19 Best Practices for Automation Testing with ...  2025-06-25T02:38:50Z
# 11  A Deep Dive Into SeaTunnel's Thread Sharing Me...  2025-06-25T02:30:19Z
# 12  Cloud Networking in Practice: Building a Highl...  2025-06-25T02:24:10Z
# 13  Impact Analysis: Google Donating A2A Protocol ...  2025-06-25T02:22:17Z
# 15     5 Smart AI Tools That Supercharge Productivity  2025-06-25T02:14:55Z
# 16  From @Attribute to HostAttributeToken: A Moder...  2025-06-25T02:02:44Z
# 17  Top 15+ Must-Have Resources for Exploring Mixe...  2025-06-25T02:02:24Z
# 18  Boost Performance & Simplify Microservices: Th...  2025-06-25T02:01:49Z
# 19  The Importance of Data Quality in AI-based Tes...  2025-06-25T01:59:30Z
# 20                        How to Install NVM on macOS  2025-06-25T01:41:37Z
# 21  No More Boring Roadmaps — I Built an AI That D...  2025-06-25T01:38:27Z
# 22  HarmonyOS Flutter Wakelock Plugin (Screen Wake...  2025-06-25T01:18:12Z
# 23  HarmonyOS Flutter Video Trimmer (Video Clippin...  2025-06-25T01:17:45Z
#
#                       Authors  \
# 0            Chaitanya Chopde
# 1                Alex Stewart
# 3                   Dev Patel
# 4                     saijami
# 5                     Sivaram
# 6                  shaohushuo
# 7                   Stanley J
# 8          DevOps Fundamental
# 9                 jasonliu112
# 10              Harish Rajora
# 11           Apache SeaTunnel
# 12               Kene Ojiteli
# 13                         cz
# 15             Sebastian Reid
# 16  vetriselvan Panneerselvam
# 17                     Vaiber
# 18                     Vaiber
# 19                   Anil Pal
# 20              Rakshit Nayak
# 21                  Bug Blitz
# 22                     flfljh
# 23                     flfljh
#
#                                                  Tags  Reading_Time  \
# 0                   #motorpump #html #css #javascript             2
# 1                                                                 1
# 3           #machinelearning #python #datascience #ai             3
# 4                    #cdn #react #webdev #performance             2
# 5                     #cloudflare #webdev #devops #ai             3
# 6                                 #harmonyos #harmony             4
# 7               #api #programming #webdev #javascript             1
# 8     #gcp #googlecloud #devops #containeranalysisapi             8
# 9                                         #emmc #ddr4             1
# 10  #automationtesting #node #softwaretesting #lam...            14
# 11                                                                4
# 12                   #aws #vpc #terraform #networking             9
# 13                                               #a2a             3
# 15                  #tech #ai #automation #technology            14
# 16   #angular #javascript #typescript #injectiontoken             3
# 17  #mixedreality #xr #spatialcomputing #augmented...             5
# 18         #microservices #api #architecture #backend             7
# 19                                                                3
# 20                            #programming #nvm #node             1
# 21               #webdev #javascript #programming #ai             1
# 22                                                                3
# 23                                                                2
#
#                                       Article_Content  Word_Count Sentiment  \
# 0   This blog is part of my @devsyncin  learning j...         304  Positive
# 1      As you can tell by this video, we've been h...          84  Positive
# 3   Imagine two artists locked in a fierce competi...         445  Positive
# 4   Leverage a CDN to slash load times and offload...         165  Positive
# 5   Forget managing regions, orchestrators, or art...         217  Positive
# 6   This article provides a very detailed introduc...         466  Positive
# 7                                                               0  Positive
# 8   The modern software landscape is characterized...         450  Positive
# 9   As DDR4 and eMMC prices skyrocket due to produ...          91  Positive
# 10  Node.js has become one of the most popular fra...        1923  Positive
# 11  The Apache SeaTunnel Zeta engine is a dedicate...         497  Positive
# 12  After grasping the concepts of Networking, Sub...         337  Positive
# 13  Google's donation of the Agent2Agent (A2A) pro...         251  Positive
# 15  What would you do with an extra 21.8 hours a w...        2454  Positive
# 16  Hey devs! 👋 As promised, we're continuing our ...         169  Positive
# 17  Welcome, fellow explorers of the digital front...         366  Positive
# 18  The Power of API Gateway Aggregation: Simplify...         534  Positive
# 19   In the era of AI-driven software development,...         661  Positive
# 20  If you're a developer working with Node.js, ma...         130  Positive
# 21  Are you tired of static roadmap templates that...         180  Positive
# 22  Defining the Wakelock API  Integrating with Fl...           9  Positive
# 23  videotrimmer is a third-party library for vide...          34  Positive
#
#     Compound_Score Language
# 0            0.296  English
# 1            0.296  English
# 3            0.296  English
# 4            0.296  English
# 5            0.296  English
# 6            0.296  English
# 7            0.296  English
# 8            0.296  English
# 9            0.296  English
# 10           0.296  English
# 11           0.296  English
# 12           0.296  English
# 13           0.296  English
# 15           0.296  English
# 16           0.296  English
# 17           0.296  English
# 18           0.296  English
# 19           0.296  English
# 20           0.296  English
# 21           0.296  English
# 22           0.296  English
# 23           0.296  English

# %%
#CREATE TABLE IF NOT EXISTS  article
#(
 #   Link Text Primary Key,
#	Title Text,
#	Time_Uploaded TIMESTAMP,
#	Authors Text,
#	Tags Text,
#	Reading_Time Integer,
#	Article_Content Text,
#	Word_Count Integer,
#	Sentiment Text,
#	Compound_Score Numeric,
#	Language Text
#	);

# %%
import psycopg2
db_parms = {
    "dbname": "postgres" ,
    "user": os.getenv("DB_USER") ,
    "password" :os.getenv("DB_PASSWORD"),
    "host" : os.getenv("DB_HOST"),
    "port" :"5432"
}

try:
    #connect to postgreSQL
    conn = psycopg2.connect (**db_parms)
    cursor = conn.cursor()
    
    #sql insert query
    insert_query ="""
    Insert Into articles (Link, Title, Time_Uploaded, Authors, Tags, Reading_Time, Article_Content ,Word_Count, Sentiment, Compound_Score, Language )
    Values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
    ON CONFLICT (Link) DO NOTHING
    """
    
    # insert DataFrame records one by one
    for _, row in merge_df.iterrows():
        cursor.execute(insert_query,(
            row['Link'], row['Title'],row['Time_Uploaded'] ,row['Authors'], row['Tags'], row['Reading_Time'],
            row['Article_Content'],row['Word_Count'],row['Sentiment'], row['Compound_Score'],row['Language']
        ))
        
    #commit 
    conn.commit()   
    print ("Data inserted successfully!")

except Exception as e:
    print(e)
    
finally:
    if conn:
        cursor.close () 
        conn.close
# Out:
# 'Word_Count'

# %%
print("Total rows in merge_df:", len(merge_df))
# Out:
# Total rows in merge_df: 19
